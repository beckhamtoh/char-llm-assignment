# %%
# !git clone https://github.com/beckhamtoh/char-llm-assignment.git
# %cd char-llm-assignment
# Out:
# Cloning into 'char-llm-assignment'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 175 (delta 83), reused 128 (delta 43), pack-reused 0 (from 0)
# Receiving objects: 100% (175/175), 32.53 MiB | 23.91 MiB/s, done.
# Resolving deltas: 100% (83/83), done.
# /kaggle/working/char-llm-assignment/char-llm-assignment/char-llm-assignment/char-llm-assignment

# %%
# Enable autoreload of local Python modules (e.g., models)
# %load_ext autoreload
# %autoreload 2

# manual reload for local modules
import importlib

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
import jax
import jax.numpy as jnp
import optax
import time

# local imports
import models.models as models
import util.generation as generation

# %%
# initialize the jax random key
key = jax.random.key(0)

# %% [markdown]
# # Load data

# %%
# load the ./data/text8_train.txt and ./data/text8_test.txt files
with open("./data/text8_train.txt", "r") as f:
    train_text = f.read()
with open("./data/text8_test.txt", "r") as f:
    test_text = f.read()

# print the length of the training text and test text
print(f"Length of training text: {len(train_text):_} characters")
print(f"Length of test text: {len(test_text):_} characters")
# Out:
# Length of training text: 90_000_000 characters
# Length of test text: 5_000_000 characters

# %%
# Build vocabulary (lowercase + space + a few punctuations)
char_set = list("abcdefghijklmnopqrstuvwxyz ")
char_to_int = {ch:i for i,ch in enumerate(char_set)}
int_to_char = {i:ch for ch,i in char_to_int.items()}

def encode(s):
    """Encode string to array of integers"""
    ids = [char_to_int[c] for c in s]
    return np.array(ids, dtype=np.uint8)  # use np.uint8 to save space

# %%
# encode the text
train_text_int = encode(train_text)
test_text_int = encode(test_text)

# %%
# sanity check: display a few random characters from the training text
T = 128
for _ in range(5):
    # choose random position in text
    N = np.random.randint(low=0, high=len(train_text)-T)
    print(train_text[N:N+T])
    print()
# Out:
# nine three five carol shields american born novelist d two zero zero three one nine three six sally kellerman american actress o
#
# o zero zero four it appears that these measures will result in eta leadership moving into different hands it is too soon to eval
#
# e and of being more expensive than petrol vehicles in addition before the mandatory reduction of sulphur in on road diesel fuel
#
# ers died because of harsh conditions or were executed pogroms one nine three eight one nine four one many scholars date the begi
#
# churches rejection of the new testament epistles a stance which has not won acceptance from any other denomination whereas jews

# %% [markdown]
# # Create a basic Transformer model

# %%
def create_train_state(rng, model_type="transformer", vocab_size=27, d_model=64, n_layers=6, n_heads=8, max_len=128):
    """Create model and initialize parameters.
    
    Args:
        model_type: either "transformer" or "lstm"
        other args same as before
    """
    if model_type == "lstm":
        # create LSTM model (doesn't need n_heads or max_len)
        model = models.CharLSTM(vocab_size, d_model, n_layers)
    else:
        # create a basic Transformer model
        model = models.DecoderOnlyTransformer(vocab_size, d_model, n_layers, n_heads, max_len)
    
    # create a dummy input for initialization
    dummy = jnp.zeros((1, min(16, max_len)), dtype=jnp.int32)
    # pass the dummy input to the model to initialize the parameters
    params = model.init({"params": rng}, dummy)["params"]
    return model, params

# %%
# vocab size
vocab_size= len(char_set)

# internal model dimensions
d_model=256

# number of attention heads
n_heads=8

# number of Transformer layers
n_layers=2

# maximum sequence length
max_len=128

# Choose model type: "transformer" or "lstm"
model_type = "lstm"  # Change this to "transformer" to use transformer

model, params = create_train_state(key, model_type=model_type, vocab_size=vocab_size, 
                                   d_model=d_model, n_layers=n_layers, 
                                   n_heads=n_heads, max_len=max_len)

# %%
# compute the number of parameters
def count_params(params):
    return sum(x.size for x in jax.tree_util.tree_leaves(params))
print(f"Number of parameters: {count_params(params):_}")
# Out:
# Number of parameters: 1_064_448

# %%
# sanity check: create a batch of data & run a forward pass
B, T = 4, 32
batch = jax.random.randint(
    key=key,
    shape=(B, T), minval=0, maxval=len(char_set))

# Handle both transformer (returns logits) and LSTM (returns logits, state)
output = model.apply({"params": params}, batch)

# Unpack if it's a tuple (LSTM), otherwise use as-is (Transformer)
if isinstance(output, tuple):
    logits, state = output
else:
    logits = output

print("batch shape:", batch.shape)  # (B, T)
print("logits shape:", logits.shape)  # (B, T, vocab_size)
# Out:
# batch shape: (4, 32)
# logits shape: (4, 32, 27)

# %% [markdown]
# # Loss function

# %%
@jax.jit
def loss_and_metrics(logits, targets):
    """Compute cross-entropy loss and accuracy.

    Assumes `targets` contains only valid integer class ids in [0, V-1] (no -1 ignore tokens).

    Args:
      logits: (B, T, V) float array of unnormalized scores.
      targets: (B, T) integer array with ground-truth class ids.

    Returns:
      loss: scalar average cross-entropy over all positions.
      metrics: dict with keys "loss" and "acc" (both scalars).
    """
    # Flatten batch/time dims so optax works on shape (N, V) and (N,)
    vocab = logits.shape[-1]
    flat_logits = logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)

    # Per-position cross-entropy, then mean over all positions
    per_pos = optax.softmax_cross_entropy_with_integer_labels(flat_logits, flat_targets)
    loss = per_pos.mean()

    # prediction over all positions
    preds = jnp.argmax(logits, axis=-1)  # (B, T)

    # compute accuracy over only the last position
    is_match = preds == targets

    # Accuracy over all positions
    acc_all = jnp.mean(is_match.astype(jnp.float32))

    # Accuracy over only last position
    acc_last = jnp.mean(is_match.astype(jnp.float32)[:,-1])

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %% [markdown]
# # Optimization step:

# %%
# create an update function
def train_step(params, opt_state, x, y, tx, dropout_key):  # ADD dropout_key
    """Single optimization step using optax optimizer.

    Args:
      params: pytree of model parameters.
      opt_state: optax optimizer state corresponding to `params`.
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
      tx: optax.GradientTransformation (already initialized).
      dropout_key: PRNG key for dropout.

    Returns:
      new_params: updated parameters after one gradient step.
      new_opt_state: updated optimizer state.
      metrics: dict of scalar metrics (loss, acc).
    """
    def loss_fn(params):
        logits, _ = model.apply({"params": params}, x, 
                              deterministic=False,  # Enable dropout during training
                              rngs={'dropout': dropout_key})
        loss, metrics = loss_and_metrics(logits, y)
        return loss, metrics

    # compute gradients (loss is scalar, metrics is auxiliary)
    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)

    # optax update: compute parameter updates and new optimizer state
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    return new_params, new_opt_state, metrics

# RE-JIT with the new signature (MUST be after the function definition)
train_step = jax.jit(train_step, static_argnames=("tx",))

# %% [markdown]
# # Batch creation:

# %%
# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# %% [markdown]
# # Optimizer creation:

# %%
# define optax optimizer
learning_rate = 0.001
# Create Adam optimizer (Optax)
tx = optax.adam(learning_rate=learning_rate)
# Initialize optimizer state for current params
opt_state = tx.init(params)
print(f"Initialized optimizer: Adam lr={learning_rate}")
# Out:
# Initialized optimizer: Adam lr=0.001

# %%
niter = 100_000
B, T = 128, 32
loss_history = []
time_history = []
time_test_history = []
loss_test_history = []
time_start = time.time()

# Create a PRNG key for dropout
dropout_rng = jax.random.PRNGKey(1)

for it in range(niter):
    batch = get_batch(train_text_int, B, T)
    input, target = batch[0], batch[1]

    # Split the dropout key for this iteration
    dropout_rng, dropout_key = jax.random.split(dropout_rng)
    
    params_new, opt_state_new, metrics = train_step(params, opt_state, input, target, tx, dropout_key)

    # update params and opt_state
    params = params_new
    opt_state = opt_state_new
    acc = metrics['acc']
    acc_last = metrics['acc_last']
    loss = metrics['loss']

    loss_history.append(loss)
    time_history.append(time.time() - time_start)

    if it % (niter // 50) == 0 or it == niter - 1:
        time_since_start = time.time() - time_start
        # compute loss on test set
        B_test, T_test = 1024, 32
        test_batch = get_batch(test_text_int, B_test, T_test)
        test_input, test_target = test_batch[0], test_batch[1]
        test_logits, _ = model.apply({"params": params}, test_input)
        test_loss, test_metrics = loss_and_metrics(test_logits, test_target)
        test_acc = test_metrics['acc']
        test_acc_last = test_metrics['acc_last']
        loss_test_history.append(test_loss)
        time_test_history.append(time_since_start)
        print(f"iteration {it:_}  time: {time_since_start:.1f} seconds")
        print(f"\t \t loss(train :: test): {loss:.4f} :: {test_loss:.4f}")
        print(f"\t \t accuracy (train :: test): {100*acc:.1f}% :: {100*test_acc:.1f}%")
        print(f"\t \t accuracy (last character) (train :: test): {100*acc_last:.1f}% :: {100*test_acc_last:.1f}%")
        print()
# Out:
# iteration 0  time: 31.4 seconds
# 	 	 loss(train :: test): 3.2959 :: 3.2826
# 	 	 accuracy (train :: test): 2.6% :: 17.1%
# 	 	 accuracy (last character) (train :: test): 3.1% :: 16.6%
#
# iteration 2_000  time: 63.0 seconds
# 	 	 loss(train :: test): 1.4887 :: 1.4996
# 	 	 accuracy (train :: test): 53.6% :: 53.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 54.4%
#
# iteration 4_000  time: 94.0 seconds
# 	 	 loss(train :: test): 1.4375 :: 1.4048
# 	 	 accuracy (train :: test): 56.4% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 59.3%
#
# iteration 6_000  time: 124.2 seconds
# 	 	 loss(train :: test): 1.3713 :: 1.3614
# 	 	 accuracy (train :: test): 57.2% :: 57.5%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 59.7%
#
# iteration 8_000  time: 154.7 seconds
# 	 	 loss(train :: test): 1.3846 :: 1.3642
# 	 	 accuracy (train :: test): 57.2% :: 57.6%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 60.6%
#
# iteration 10_000  time: 185.2 seconds
# 	 	 loss(train :: test): 1.3751 :: 1.3602
# 	 	 accuracy (train :: test): 57.5% :: 57.6%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 58.2%
#
# iteration 12_000  time: 215.6 seconds
# 	 	 loss(train :: test): 1.3873 :: 1.3595
# 	 	 accuracy (train :: test): 56.1% :: 57.4%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 59.1%
#
# iteration 14_000  time: 245.9 seconds
# 	 	 loss(train :: test): 1.3478 :: 1.3546
# 	 	 accuracy (train :: test): 56.8% :: 57.8%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 60.4%
#
# iteration 16_000  time: 276.5 seconds
# 	 	 loss(train :: test): 1.3730 :: 1.3352
# 	 	 accuracy (train :: test): 57.2% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.6%
#
# iteration 18_000  time: 306.9 seconds
# 	 	 loss(train :: test): 1.3646 :: 1.3546
# 	 	 accuracy (train :: test): 56.8% :: 57.5%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 61.4%
#
# iteration 20_000  time: 337.4 seconds
# 	 	 loss(train :: test): 1.2970 :: 1.3403
# 	 	 accuracy (train :: test): 59.0% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 62.5%
#
# iteration 22_000  time: 367.9 seconds
# 	 	 loss(train :: test): 1.3867 :: 1.3257
# 	 	 accuracy (train :: test): 55.4% :: 58.1%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 57.6%
#
# iteration 24_000  time: 398.4 seconds
# 	 	 loss(train :: test): 1.3747 :: 1.3289
# 	 	 accuracy (train :: test): 57.0% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 63.6%
#
# iteration 26_000  time: 428.9 seconds
# 	 	 loss(train :: test): 1.2899 :: 1.3443
# 	 	 accuracy (train :: test): 59.4% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 59.3%
#
# iteration 28_000  time: 459.5 seconds
# 	 	 loss(train :: test): 1.3005 :: 1.3382
# 	 	 accuracy (train :: test): 59.3% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 60.4%
#
# iteration 30_000  time: 490.0 seconds
# 	 	 loss(train :: test): 1.3347 :: 1.3310
# 	 	 accuracy (train :: test): 57.8% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 62.6%
#
# iteration 32_000  time: 520.6 seconds
# 	 	 loss(train :: test): 1.3466 :: 1.3351
# 	 	 accuracy (train :: test): 57.3% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 62.6%
#
# iteration 34_000  time: 551.2 seconds
# 	 	 loss(train :: test): 1.3268 :: 1.3324
# 	 	 accuracy (train :: test): 58.3% :: 58.0%
# 	 	 accuracy (last character) (train :: test): 68.0% :: 64.2%
#
# iteration 36_000  time: 581.7 seconds
# 	 	 loss(train :: test): 1.3669 :: 1.3226
# 	 	 accuracy (train :: test): 57.3% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 61.5%
#
# iteration 38_000  time: 612.2 seconds
# 	 	 loss(train :: test): 1.3497 :: 1.3344
# 	 	 accuracy (train :: test): 58.2% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 59.9%
#
# iteration 40_000  time: 642.7 seconds
# 	 	 loss(train :: test): 1.3186 :: 1.3286
# 	 	 accuracy (train :: test): 59.1% :: 57.9%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 61.2%
#
# iteration 42_000  time: 673.2 seconds
# 	 	 loss(train :: test): 1.3640 :: 1.3117
# 	 	 accuracy (train :: test): 56.8% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 61.0%
#
# iteration 44_000  time: 703.7 seconds
# 	 	 loss(train :: test): 1.3513 :: 1.3185
# 	 	 accuracy (train :: test): 57.4% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 62.9%
#
# iteration 46_000  time: 734.2 seconds
# 	 	 loss(train :: test): 1.3394 :: 1.3261
# 	 	 accuracy (train :: test): 58.0% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 60.8%
#
# iteration 48_000  time: 764.7 seconds
# 	 	 loss(train :: test): 1.3070 :: 1.3139
# 	 	 accuracy (train :: test): 59.2% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 58.1%
#
# iteration 50_000  time: 795.2 seconds
# 	 	 loss(train :: test): 1.3713 :: 1.3161
# 	 	 accuracy (train :: test): 57.5% :: 58.7%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 63.6%
#
# iteration 52_000  time: 825.7 seconds
# 	 	 loss(train :: test): 1.3721 :: 1.3296
# 	 	 accuracy (train :: test): 56.7% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 61.8%
#
# iteration 54_000  time: 856.1 seconds
# 	 	 loss(train :: test): 1.3107 :: 1.3331
# 	 	 accuracy (train :: test): 58.6% :: 58.1%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 61.9%
#
# iteration 56_000  time: 886.6 seconds
# 	 	 loss(train :: test): 1.3113 :: 1.3123
# 	 	 accuracy (train :: test): 58.2% :: 58.9%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 62.3%
#
# iteration 58_000  time: 917.1 seconds
# 	 	 loss(train :: test): 1.3344 :: 1.3230
# 	 	 accuracy (train :: test): 58.0% :: 58.4%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 62.9%
#
# iteration 60_000  time: 947.5 seconds
# 	 	 loss(train :: test): 1.3292 :: 1.3229
# 	 	 accuracy (train :: test): 57.8% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 60.8%
#
# iteration 62_000  time: 977.9 seconds
# 	 	 loss(train :: test): 1.3439 :: 1.3094
# 	 	 accuracy (train :: test): 57.2% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 63.8%
#
# iteration 64_000  time: 1008.4 seconds
# 	 	 loss(train :: test): 1.3318 :: 1.3122
# 	 	 accuracy (train :: test): 59.3% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 63.4%
#
# iteration 66_000  time: 1038.9 seconds
# 	 	 loss(train :: test): 1.3541 :: 1.3097
# 	 	 accuracy (train :: test): 57.9% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 61.2%
#
# iteration 68_000  time: 1069.4 seconds
# 	 	 loss(train :: test): 1.3467 :: 1.3041
# 	 	 accuracy (train :: test): 57.7% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 62.6%
#
# iteration 70_000  time: 1099.9 seconds
# 	 	 loss(train :: test): 1.3299 :: 1.2942
# 	 	 accuracy (train :: test): 59.2% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 63.8%
#
# iteration 72_000  time: 1130.5 seconds
# 	 	 loss(train :: test): 1.3110 :: 1.2948
# 	 	 accuracy (train :: test): 58.5% :: 59.6%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 61.8%
#
# iteration 74_000  time: 1161.1 seconds
# 	 	 loss(train :: test): 1.3641 :: 1.3135
# 	 	 accuracy (train :: test): 57.4% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 64.2%
#
# iteration 76_000  time: 1191.6 seconds
# 	 	 loss(train :: test): 1.3470 :: 1.3171
# 	 	 accuracy (train :: test): 57.4% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 59.5%
#
# iteration 78_000  time: 1222.1 seconds
# 	 	 loss(train :: test): 1.3127 :: 1.2914
# 	 	 accuracy (train :: test): 59.2% :: 59.4%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 61.7%
#
# iteration 80_000  time: 1252.6 seconds
# 	 	 loss(train :: test): 1.3341 :: 1.3190
# 	 	 accuracy (train :: test): 57.9% :: 58.3%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.7%
#
# iteration 82_000  time: 1283.2 seconds
# 	 	 loss(train :: test): 1.2784 :: 1.3159
# 	 	 accuracy (train :: test): 59.9% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 59.6%
#
# iteration 84_000  time: 1313.6 seconds
# 	 	 loss(train :: test): 1.3407 :: 1.3296
# 	 	 accuracy (train :: test): 58.6% :: 58.2%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 60.4%
#
# iteration 86_000  time: 1344.2 seconds
# 	 	 loss(train :: test): 1.3195 :: 1.3191
# 	 	 accuracy (train :: test): 59.4% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 61.9%
#
# iteration 88_000  time: 1374.7 seconds
# 	 	 loss(train :: test): 1.3379 :: 1.3157
# 	 	 accuracy (train :: test): 57.9% :: 58.9%
# 	 	 accuracy (last character) (train :: test): 48.4% :: 61.9%
#
# iteration 90_000  time: 1405.2 seconds
# 	 	 loss(train :: test): 1.3586 :: 1.2976
# 	 	 accuracy (train :: test): 57.4% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 64.2%
#
# iteration 92_000  time: 1435.8 seconds
# 	 	 loss(train :: test): 1.3664 :: 1.2999
# 	 	 accuracy (train :: test): 56.7% :: 59.1%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 60.6%
#
# iteration 94_000  time: 1466.4 seconds
# 	 	 loss(train :: test): 1.2982 :: 1.3100
# 	 	 accuracy (train :: test): 59.6% :: 58.5%
# 	 	 accuracy (last character) (train :: test): 68.8% :: 62.4%
#
# iteration 96_000  time: 1496.9 seconds
# 	 	 loss(train :: test): 1.3128 :: 1.3108
# 	 	 accuracy (train :: test): 58.8% :: 58.8%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 61.6%
#
# iteration 98_000  time: 1527.5 seconds
# 	 	 loss(train :: test): 1.3036 :: 1.3231
# 	 	 accuracy (train :: test): 58.0% :: 58.6%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 61.3%
#
# iteration 99_999  time: 1558.1 seconds
# 	 	 loss(train :: test): 1.3223 :: 1.3066
# 	 	 accuracy (train :: test): 58.9% :: 59.0%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 62.4%

# %%
# plot the loss history
import matplotlib.pyplot as plt
plt.plot(time_history, loss_history, '-', label='train', color="blue")
plt.plot(time_test_history, loss_test_history, '-', label='test', lw=2, color="red")
plt.xlabel("Time (seconds)")
plt.ylabel("Loss")
plt.legend(loc='upper right')
plt.title("Training Loss History")
plt.grid()

# %%
# Generation (only works with transformer)
if model_type == "transformer":
    B = 1
    seed = 42
    rng = jax.random.PRNGKey(seed)
    prompt = "hello my fri"
    # prompt_int = encode(prompt.lower())
    prompt_int = jnp.array([ [char_to_int.get(c, len(char_set)) for c in prompt.lower()[:64]] ], dtype=jnp.int32)
    gen_len = 1000
    out_ids = generation.generate_tokens(model, params, rng, prompt_int, gen_len, block_size=64, temperature=0.7, sample=True)
    print('generated ids shape:', out_ids.shape)
    print('generated text:')
    generated_text = ''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0]))
    # concatenate with prompt
    print(prompt + generated_text)
else:
    print(f"Generation skipped for {model_type} model.")
    print("LSTM model trained successfully. Check test accuracy above.")
# Out:
# Generation skipped for lstm model.
# LSTM model trained successfully. Check test accuracy above.
