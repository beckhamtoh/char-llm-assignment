# %%
# !git clone https://github.com/beckhamtoh/char-llm-assignment.git
# %cd char-llm-assignment
# Out:
# Cloning into 'char-llm-assignment'...
# /usr/local/lib/python3.12/pty.py:95: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# remote: Enumerating objects: 197, done.
# remote: Total 197 (delta 0), reused 0 (delta 0), pack-reused 197 (from 1)
# Receiving objects: 100% (197/197), 33.01 MiB | 35.92 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# /kaggle/working/char-llm-assignment/char-llm-assignment

# %%
# Enable autoreload of local Python modules (e.g., models)
# %load_ext autoreload
# %autoreload 2

# manual reload for local modules
import importlib

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
import jax
import jax.numpy as jnp
import optax
import time
import matplotlib.pyplot as plt

# local imports
import models.models as models
import util.generation as generation

# %%
# initialize the jax random key
key = jax.random.key(0)

# %% [markdown]
# # Load data

# %%
# load the ./data/text8_train.txt and ./data/text8_test.txt files
with open("./data/text8_train.txt", "r") as f:
    train_text = f.read()
with open("./data/text8_test.txt", "r") as f:
    test_text = f.read()

# print the length of the training text and test text
print(f"Length of training text: {len(train_text):_} characters")
print(f"Length of test text: {len(test_text):_} characters")
# Out:
# Length of training text: 90_000_000 characters
# Length of test text: 5_000_000 characters

# %%
# Build vocabulary (lowercase + space + a few punctuations)
char_set = list("abcdefghijklmnopqrstuvwxyz ")
char_to_int = {ch:i for i,ch in enumerate(char_set)}
int_to_char = {i:ch for ch,i in char_to_int.items()}

def encode(s):
    """Encode string to array of integers"""
    ids = [char_to_int[c] for c in s]
    return np.array(ids, dtype=np.uint8)  # use np.uint8 to save space

# %%
# encode the text
train_text_int = encode(train_text)
test_text_int = encode(test_text)

# %%
# sanity check: display a few random characters from the training text
T = 128
for _ in range(5):
    # choose random position in text
    N = np.random.randint(low=0, high=len(train_text)-T)
    print(train_text[N:N+T])
    print()
# Out:
# e top level domain gf see also french guiana communications by country communications in french guiana railways zero km one nine
#
# he environmental aspects of aviation in one nine six eight when it received the power to set aircraft noise standards legislatio
#
# m from the classical music critics while being scorned by the popular music press whilst composing it costello deliberately avoi
#
#  nine six pp seven eight isbn zero one nine eight five one eight eight nine seven henk tijms understanding probability cambridge
#
# l authority b h roberts an ardent proponent of evolution and the more conservative theologian joseph fielding smith this prompte

# %% [markdown]
# # Create a basic Transformer model

# %%
def create_train_state(rng, vocab_size=27, d_model=64, n_layers=6, n_heads=8, max_len=128):
    # create a basic Transformer model
    model = models.DecoderOnlyTransformer(vocab_size, d_model, n_layers, n_heads, max_len)
    # create a dummy input for initialization
    dummy = jnp.zeros((1, min(16, max_len)), dtype=jnp.int32)
    # pass the dummy input to the model to initialize the parameters
    params = model.init({"params": rng}, dummy)["params"]
    return model, params

# %%
# vocab size
vocab_size= len(char_set)

# internal model dimensions
d_model=256

# number of attention heads
n_heads=8

# number of Transformer layers
n_layers=2

# maximum sequence length
max_len=128

model, params = create_train_state(key, vocab_size, d_model, n_layers, n_heads, max_len)

# %%
# compute the number of parameters
def count_params(params):
    return sum(x.size for x in jax.tree_util.tree_leaves(params))
print(f"Number of parameters: {count_params(params):_}")
# Out:
# Number of parameters: 1_624_576

# %%
# sanity check: create a batch of data & run a forward pass
B, T = 4, 32
batch = jax.random.randint(
    key=key,
    shape=(B, T), minval=0, maxval=len(char_set))
logits = model.apply({"params": params}, batch)

print("batch shape:", batch.shape)  # (B, T)
print("logits shape:", logits.shape)  # (B, T, vocab_size)
# Out:
# batch shape: (4, 32)
# logits shape: (4, 32, 27)

# %% [markdown]
# # Loss function

# %% [markdown]
# ### Loss everywhere vs. loss at last token
#
# last_token_only = False vs last_token_only = True

# %%
def loss_and_metrics(logits, targets, last_token_only=False):
    """Compute cross-entropy loss and accuracy.
    Args:
        logits: (B, T, V) float array of unnormalized scores.
        targets: (B, T) integer array with ground-truth class ids.
        last_token_only: If True, compute loss only on the last token position.
    Returns:
        loss: scalar average cross-entropy.
        metrics: dict with keys "loss", "acc", and "acc_last".
    """
    vocab = logits.shape[-1]
    flat_logits = logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)
    
    # Compute per-position cross-entropy
    per_pos = optax.softmax_cross_entropy_with_integer_labels(flat_logits, flat_targets)
    per_pos = per_pos.reshape(targets.shape)  # (B, T)
    
    # Use jax.lax.cond for conditional logic
    def compute_full_loss(per_pos):
        return per_pos.mean()
    
    def compute_last_loss(per_pos):
        return per_pos[:, -1].mean()
    
    loss = jax.lax.cond(
        last_token_only,
        compute_last_loss,
        compute_full_loss,
        per_pos
    )
    
    # Predictions and accuracy
    preds = jnp.argmax(logits, axis=-1)
    is_match = preds == targets
    acc_all = jnp.mean(is_match.astype(jnp.float32))
    acc_last = jnp.mean(is_match[:, -1].astype(jnp.float32))
    
    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# Apply JIT after defining
loss_and_metrics = jax.jit(loss_and_metrics, static_argnames=['last_token_only'])

# %%
# Compute full-sequence loss
loss_full, metrics_full = loss_and_metrics(logits, targets, last_token_only=False)

# Compute last-token-only loss
loss_last, metrics_last = loss_and_metrics(logits, targets, last_token_only=True)

# Print comparison
print("=== Comparison: Full-sequence vs Last-token-only ===")
print(f"Loss (full sequence): {loss_full:.4f}")
print(f"Loss (last token only): {loss_last:.4f}\n")
print("Accuracy over all positions:")
print(f"Full sequence: {metrics_full['acc']*100:.2f}%")
print(f"Last token only: {metrics_last['acc']*100:.2f}%\n")
print("Accuracy on last token only:")
print(f"Full sequence: {metrics_full['acc_last']*100:.2f}%")
print(f"Last token only: {metrics_last['acc_last']*100:.2f}%")
# Out:
# === Comparison: Full-sequence vs Last-token-only ===
# Loss (full sequence): 3.6685
# Loss (last token only): 3.4951
#
# Accuracy over all positions:
# Full sequence: 3.12%
# Last token only: 3.12%
#
# Accuracy on last token only:
# Full sequence: 0.00%
# Last token only: 0.00%

# %% [markdown]
# # Label smoothing
#
# - label_smoothing = 0.0 - baseline (hard labels)
# - label_smoothing = 0.05 - light smoothing
# - label_smoothing = 0.1 - standard smoothing (common choice)
# - label_smoothing = 0.2 - heavier smoothing

# %%
@jax.jit
def loss_and_metrics(logits, targets, label_smoothing=0.0):
    """Compute cross-entropy loss and accuracy."""
    vocab = logits.shape[-1]
    flat_logits = logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)

    # Always use one-hot encoding, label_smoothing=0.0 becomes hard labels
    one_hot_targets = jax.nn.one_hot(flat_targets, vocab)
    smooth_targets = one_hot_targets * (1 - label_smoothing) + label_smoothing / vocab
    per_pos = optax.softmax_cross_entropy(flat_logits, smooth_targets)
    
    loss = per_pos.mean()

    preds = jnp.argmax(logits, axis=-1)
    is_match = preds == targets
    acc_all = jnp.mean(is_match.astype(jnp.float32))
    acc_last = jnp.mean(is_match[:, -1].astype(jnp.float32))

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %%
# Modified train_step that supports label smoothing
def train_step(params, opt_state, x, y, tx, label_smoothing=0.0):
    """Single optimization step using optax optimizer.

    Args:
      params: pytree of model parameters.
      opt_state: optax optimizer state corresponding to `params`.
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
      tx: optax.GradientTransformation (already initialized).
      label_smoothing: Float in [0, 1] for label smoothing.

    Returns:
      new_params: updated parameters after one gradient step.
      new_opt_state: updated optimizer state.
      metrics: dict of scalar metrics (loss, acc).
    """
    def loss_fn(params):
        logits = model.apply({"params": params}, x)
        loss, metrics = loss_and_metrics(logits, y, label_smoothing=label_smoothing)
        return loss, metrics

    # compute gradients (loss is scalar, metrics is auxiliary)
    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)

    # optax update: compute parameter updates and new optimizer state
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    return new_params, new_opt_state, metrics

# jit: mark both tx and label_smoothing as static
train_step = jax.jit(train_step, static_argnames=("tx", "label_smoothing"))

# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# define optax optimizer
learning_rate = 0.001
# Create Adam optimizer (Optax)
tx = optax.adam(learning_rate=learning_rate)
# Initialize optimizer state for current params
opt_state = tx.init(params)
print(f"Initialized optimizer: Adam lr={learning_rate}")
# Out:
# Initialized optimizer: Adam lr=0.001

# %%
def train_with_label_smoothing(model, params_init, opt_state_init, tx, train_text_int, 
                                test_text_int, train_step_fn, get_batch, 
                                label_smoothing_values, niter=5000, B=128, T=32):
    """
    Train model with different label smoothing values and collect results.
    
    Args:
        model: The model to train
        params_init: Initial model parameters
        opt_state_init: Initial optimizer state
        tx: Optimizer
        train_text_int: Training data
        test_text_int: Test data
        train_step_fn: Training step function (should accept label_smoothing)
        get_batch: Function to get batches
        label_smoothing_values: List of label smoothing values to try
        niter: Number of training iterations
        B: Batch size
        T: Sequence length
    
    Returns:
        results: Dictionary with training histories for each smoothing value
    """
    results = {}
    
    for ls_val in label_smoothing_values:
        print(f"\n{'='*60}")
        print(f"Training with label_smoothing = {ls_val}")
        print(f"{'='*60}\n")
        
        # Reset model parameters and optimizer state for each run
        params = params_init
        opt_state = opt_state_init
        
        loss_history = []
        time_history = []
        loss_test_history = []
        acc_test_history = []
        acc_last_test_history = []
        time_test_history = []
        
        time_start = time.time()
        
        for it in range(niter):
            batch = get_batch(train_text_int, B, T)
            input, target = batch[0], batch[1]
            
            # Modified train_step to accept label_smoothing
            params_new, opt_state_new, metrics = train_step_fn(
                params, opt_state, input, target, tx, label_smoothing=ls_val  
            )
            
            params = params_new
            opt_state = opt_state_new
            acc = metrics['acc']
            acc_last = metrics['acc_last']
            loss = metrics['loss']
            
            loss_history.append(float(loss))
            time_history.append(time.time() - time_start)
            
            if it % (niter // 50) == 0 or it == niter - 1:
                time_since_start = time.time() - time_start
                
                # Compute loss on test set
                B_test, T_test = 1024, 32
                test_batch = get_batch(test_text_int, B_test, T_test)
                test_input, test_target = test_batch[0], test_batch[1]
                test_logits = model.apply({"params": params}, test_input)
                
                # Use same label_smoothing for test evaluation
                test_loss, test_metrics = loss_and_metrics(
                    test_logits, test_target, label_smoothing=ls_val
                )
                test_acc = test_metrics['acc']
                test_acc_last = test_metrics['acc_last']
                
                loss_test_history.append(float(test_loss))
                acc_test_history.append(float(test_acc))
                acc_last_test_history.append(float(test_acc_last))
                time_test_history.append(time_since_start)
                
                print(f"iteration {it:_}  time: {time_since_start:.1f} seconds")
                print(f"\t \t loss(train :: test): {loss:.4f} :: {test_loss:.4f}")
                print(f"\t \t accuracy (train :: test): {100*acc:.1f}% :: {100*test_acc:.1f}%")
                print(f"\t \t accuracy (last character) (train :: test): {100*acc_last:.1f}% :: {100*test_acc_last:.1f}%")
                print()
        
        results[ls_val] = {
            'loss_train': loss_history,
            'loss_test': loss_test_history,
            'acc_test': acc_test_history,
            'acc_last_test': acc_last_test_history,
            'time_train': time_history,
            'time_test': time_test_history
        }
    
    return results

# %%
def plot_label_smoothing_comparison(results):
    """
    Plot comparison of different label smoothing values.
    
    Args:
        results: Dictionary returned by train_with_label_smoothing()
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Label Smoothing Comparison', fontsize=16, fontweight='bold')
    
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    labels_map = {
        0.0: 'Baseline (0.0)',
        0.05: 'Light (0.05)',
        0.1: 'Standard (0.1)',
        0.2: 'Heavy (0.2)'
    }
    
    # Plot 1: Training Loss over time
    ax1 = axes[0, 0]
    for idx, (ls_val, data) in enumerate(results.items()):
        ax1.plot(data['time_train'], data['loss_train'], 
                label=labels_map.get(ls_val, f'{ls_val}'), linewidth=1.5, 
                color=colors[idx % len(colors)], alpha=0.7)
    ax1.set_xlabel('Time (seconds)', fontsize=12)
    ax1.set_ylabel('Training Loss', fontsize=12)
    ax1.set_title('Training Loss vs Time', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=10)
    ax1.grid(True, alpha=0.3)
    
    # Plot 2: Test Loss
    ax2 = axes[0, 1]
    for idx, (ls_val, data) in enumerate(results.items()):
        ax2.plot(data['time_test'], data['loss_test'], 
                label=labels_map.get(ls_val, f'{ls_val}'), linewidth=2, 
                marker='o', markersize=4, color=colors[idx % len(colors)])
    ax2.set_xlabel('Time (seconds)', fontsize=12)
    ax2.set_ylabel('Test Loss', fontsize=12)
    ax2.set_title('Test Loss vs Time', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=10)
    ax2.grid(True, alpha=0.3)
    
    # Plot 3: Test Accuracy
    ax3 = axes[1, 0]
    for idx, (ls_val, data) in enumerate(results.items()):
        acc_percent = [a * 100 for a in data['acc_test']]
        ax3.plot(data['time_test'], acc_percent, 
                label=labels_map.get(ls_val, f'{ls_val}'), linewidth=2, 
                marker='s', markersize=4, color=colors[idx % len(colors)])
    ax3.set_xlabel('Time (seconds)', fontsize=12)
    ax3.set_ylabel('Test Accuracy (%)', fontsize=12)
    ax3.set_title('Overall Test Accuracy', fontsize=13, fontweight='bold')
    ax3.legend(fontsize=10)
    ax3.grid(True, alpha=0.3)
    
    # Plot 4: Last Token Accuracy
    ax4 = axes[1, 1]
    for idx, (ls_val, data) in enumerate(results.items()):
        acc_last_percent = [a * 100 for a in data['acc_last_test']]
        ax4.plot(data['time_test'], acc_last_percent, 
                label=labels_map.get(ls_val, f'{ls_val}'), linewidth=2, 
                marker='^', markersize=4, color=colors[idx % len(colors)])
    ax4.set_xlabel('Time (seconds)', fontsize=12)
    ax4.set_ylabel('Last Token Accuracy (%)', fontsize=12)
    ax4.set_title('Last Token Test Accuracy', fontsize=13, fontweight='bold')
    ax4.legend(fontsize=10)
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig

def plot_final_comparison(results):
    """
    Create bar charts comparing final metrics.
    """
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    fig.suptitle('Final Metrics Comparison', fontsize=16, fontweight='bold')
    
    smoothing_vals = list(results.keys())
    labels = [f'{v}' for v in smoothing_vals]
    
    # Extract final values
    final_loss = [results[v]['loss_test'][-1] for v in smoothing_vals]
    final_acc = [results[v]['acc_test'][-1] * 100 for v in smoothing_vals]
    final_acc_last = [results[v]['acc_last_test'][-1] * 100 for v in smoothing_vals]
    
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
    
    # Plot 1: Final Test Loss
    ax1 = axes[0]
    bars1 = ax1.bar(labels, final_loss, color=colors[:len(labels)], alpha=0.7)
    ax1.set_xlabel('Label Smoothing', fontsize=12)
    ax1.set_ylabel('Test Loss', fontsize=12)
    ax1.set_title('Final Test Loss', fontsize=13, fontweight='bold')
    ax1.grid(True, alpha=0.3, axis='y')
    for bar in bars1:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Plot 2: Final Test Accuracy
    ax2 = axes[1]
    bars2 = ax2.bar(labels, final_acc, color=colors[:len(labels)], alpha=0.7)
    ax2.set_xlabel('Label Smoothing', fontsize=12)
    ax2.set_ylabel('Accuracy (%)', fontsize=12)
    ax2.set_title('Final Test Accuracy', fontsize=13, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')
    ax2.set_ylim([0, 100])
    for bar in bars2:
        height = bar.get_height()
        ax2.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}%', ha='center', va='bottom', fontsize=9)
    
    # Plot 3: Final Last Token Accuracy
    ax3 = axes[2]
    bars3 = ax3.bar(labels, final_acc_last, color=colors[:len(labels)], alpha=0.7)
    ax3.set_xlabel('Label Smoothing', fontsize=12)
    ax3.set_ylabel('Accuracy (%)', fontsize=12)
    ax3.set_title('Final Last Token Accuracy', fontsize=13, fontweight='bold')
    ax3.grid(True, alpha=0.3, axis='y')
    ax3.set_ylim([0, 100])
    for bar in bars3:
        height = bar.get_height()
        ax3.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}%', ha='center', va='bottom', fontsize=9)
    
    plt.tight_layout()
    return fig


def print_summary(results):
    """Print summary table of results."""
    print("\n" + "="*80)
    print("FINAL RESULTS SUMMARY")
    print("="*80)
    print(f"{'Label Smoothing':<20} {'Test Loss':<15} {'Test Acc (%)':<15} {'Last Token Acc (%)':<20}")
    print("-"*80)
    for ls_val in results.keys():
        data = results[ls_val]
        print(f"{ls_val:<20.2f} {data['loss_test'][-1]:<15.4f} "
              f"{data['acc_test'][-1]*100:<15.2f} {data['acc_last_test'][-1]*100:<20.2f}")

# %%
label_smoothing_values = [0.0, 0.05, 0.1, 0.2]

results = train_with_label_smoothing(
    model=model,
    params_init=params,  # Your initial parameters
    opt_state_init=tx.init(params),  # Initial optimizer state
    tx=tx,  # Your optimizer
    train_text_int=train_text_int,
    test_text_int=test_text_int,
    train_step_fn=train_step,
    get_batch=get_batch,
    label_smoothing_values=label_smoothing_values,
    niter=5000,
    B=128,
    T=32
)
# Out:
# ============================================================
# Training with label_smoothing = 0.0
# ============================================================
#
# iteration 0  time: 6.3 seconds
# 	 	 loss(train :: test): 1.4056 :: 1.4260
# 	 	 accuracy (train :: test): 56.4% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 54.8%
#
# iteration 100  time: 6.9 seconds
# 	 	 loss(train :: test): 1.3864 :: 1.4188
# 	 	 accuracy (train :: test): 56.9% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 57.9%
#
# iteration 200  time: 7.2 seconds
# 	 	 loss(train :: test): 1.3768 :: 1.4214
# 	 	 accuracy (train :: test): 56.8% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 71.9% :: 59.5%
#
# iteration 300  time: 7.5 seconds
# 	 	 loss(train :: test): 1.4423 :: 1.4372
# 	 	 accuracy (train :: test): 55.0% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 47.7% :: 58.0%
#
# iteration 400  time: 7.8 seconds
# 	 	 loss(train :: test): 1.3983 :: 1.4229
# 	 	 accuracy (train :: test): 56.2% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 59.0%
#
# iteration 500  time: 8.1 seconds
# 	 	 loss(train :: test): 1.3699 :: 1.4181
# 	 	 accuracy (train :: test): 57.2% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 56.4%
#
# iteration 600  time: 8.5 seconds
# 	 	 loss(train :: test): 1.4054 :: 1.4401
# 	 	 accuracy (train :: test): 55.9% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 57.0%
#
# iteration 700  time: 8.8 seconds
# 	 	 loss(train :: test): 1.4585 :: 1.4140
# 	 	 accuracy (train :: test): 54.1% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 57.3%
#
# iteration 800  time: 9.1 seconds
# 	 	 loss(train :: test): 1.3967 :: 1.4277
# 	 	 accuracy (train :: test): 55.9% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 58.7%
#
# iteration 900  time: 9.4 seconds
# 	 	 loss(train :: test): 1.3821 :: 1.4083
# 	 	 accuracy (train :: test): 56.6% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.3%
#
# iteration 1_000  time: 9.7 seconds
# 	 	 loss(train :: test): 1.3922 :: 1.4130
# 	 	 accuracy (train :: test): 56.5% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 60.0%
#
# iteration 1_100  time: 10.0 seconds
# 	 	 loss(train :: test): 1.4128 :: 1.4222
# 	 	 accuracy (train :: test): 55.7% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.5%
#
# iteration 1_200  time: 10.3 seconds
# 	 	 loss(train :: test): 1.4223 :: 1.4141
# 	 	 accuracy (train :: test): 56.2% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 56.5%
#
# iteration 1_300  time: 10.6 seconds
# 	 	 loss(train :: test): 1.3405 :: 1.4332
# 	 	 accuracy (train :: test): 57.6% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 56.6%
#
# iteration 1_400  time: 10.9 seconds
# 	 	 loss(train :: test): 1.3439 :: 1.4120
# 	 	 accuracy (train :: test): 57.9% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.1%
#
# iteration 1_500  time: 11.3 seconds
# 	 	 loss(train :: test): 1.3842 :: 1.4221
# 	 	 accuracy (train :: test): 56.2% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 56.6%
#
# iteration 1_600  time: 11.6 seconds
# 	 	 loss(train :: test): 1.3748 :: 1.3964
# 	 	 accuracy (train :: test): 57.9% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 56.8%
#
# iteration 1_700  time: 11.9 seconds
# 	 	 loss(train :: test): 1.4228 :: 1.4084
# 	 	 accuracy (train :: test): 55.3% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 57.6%
#
# iteration 1_800  time: 12.2 seconds
# 	 	 loss(train :: test): 1.3943 :: 1.4010
# 	 	 accuracy (train :: test): 56.0% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 56.9%
#
# iteration 1_900  time: 12.5 seconds
# 	 	 loss(train :: test): 1.4179 :: 1.4374
# 	 	 accuracy (train :: test): 55.7% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 56.6%
#
# iteration 2_000  time: 12.8 seconds
# 	 	 loss(train :: test): 1.3890 :: 1.4155
# 	 	 accuracy (train :: test): 56.3% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 56.6%
#
# iteration 2_100  time: 13.1 seconds
# 	 	 loss(train :: test): 1.3874 :: 1.4024
# 	 	 accuracy (train :: test): 56.0% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 58.1%
#
# iteration 2_200  time: 13.4 seconds
# 	 	 loss(train :: test): 1.3662 :: 1.4413
# 	 	 accuracy (train :: test): 56.9% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 54.3%
#
# iteration 2_300  time: 13.7 seconds
# 	 	 loss(train :: test): 1.5011 :: 1.4083
# 	 	 accuracy (train :: test): 53.8% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 60.8%
#
# iteration 2_400  time: 14.0 seconds
# 	 	 loss(train :: test): 1.3999 :: 1.4095
# 	 	 accuracy (train :: test): 55.8% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.5%
#
# iteration 2_500  time: 14.4 seconds
# 	 	 loss(train :: test): 1.3578 :: 1.3763
# 	 	 accuracy (train :: test): 57.4% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 57.8%
#
# iteration 2_600  time: 14.7 seconds
# 	 	 loss(train :: test): 1.3843 :: 1.4156
# 	 	 accuracy (train :: test): 56.5% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 58.6%
#
# iteration 2_700  time: 15.0 seconds
# 	 	 loss(train :: test): 1.3222 :: 1.3821
# 	 	 accuracy (train :: test): 57.6% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 56.6%
#
# iteration 2_800  time: 15.3 seconds
# 	 	 loss(train :: test): 1.4224 :: 1.3993
# 	 	 accuracy (train :: test): 56.1% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 56.2%
#
# iteration 2_900  time: 15.6 seconds
# 	 	 loss(train :: test): 1.3382 :: 1.4197
# 	 	 accuracy (train :: test): 58.1% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 60.4%
#
# iteration 3_000  time: 15.9 seconds
# 	 	 loss(train :: test): 1.3510 :: 1.4040
# 	 	 accuracy (train :: test): 57.8% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.1%
#
# iteration 3_100  time: 16.2 seconds
# 	 	 loss(train :: test): 1.3516 :: 1.3916
# 	 	 accuracy (train :: test): 58.3% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 60.0%
#
# iteration 3_200  time: 16.5 seconds
# 	 	 loss(train :: test): 1.3705 :: 1.4152
# 	 	 accuracy (train :: test): 56.8% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 57.4%
#
# iteration 3_300  time: 16.8 seconds
# 	 	 loss(train :: test): 1.3754 :: 1.3978
# 	 	 accuracy (train :: test): 57.0% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.7%
#
# iteration 3_400  time: 17.1 seconds
# 	 	 loss(train :: test): 1.3702 :: 1.3909
# 	 	 accuracy (train :: test): 56.5% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 60.4%
#
# iteration 3_500  time: 17.4 seconds
# 	 	 loss(train :: test): 1.3836 :: 1.4216
# 	 	 accuracy (train :: test): 57.1% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 57.1%
#
# iteration 3_600  time: 17.7 seconds
# 	 	 loss(train :: test): 1.3669 :: 1.3999
# 	 	 accuracy (train :: test): 56.5% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 57.4%
#
# iteration 3_700  time: 18.1 seconds
# 	 	 loss(train :: test): 1.3788 :: 1.4019
# 	 	 accuracy (train :: test): 57.5% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 57.7%
#
# iteration 3_800  time: 18.4 seconds
# 	 	 loss(train :: test): 1.3549 :: 1.3987
# 	 	 accuracy (train :: test): 57.5% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 59.1%
#
# iteration 3_900  time: 18.7 seconds
# 	 	 loss(train :: test): 1.3743 :: 1.3874
# 	 	 accuracy (train :: test): 58.7% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 58.3%
#
# iteration 4_000  time: 19.0 seconds
# 	 	 loss(train :: test): 1.3398 :: 1.3944
# 	 	 accuracy (train :: test): 58.1% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.8%
#
# iteration 4_100  time: 19.3 seconds
# 	 	 loss(train :: test): 1.3936 :: 1.3790
# 	 	 accuracy (train :: test): 55.9% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 58.7%
#
# iteration 4_200  time: 19.6 seconds
# 	 	 loss(train :: test): 1.3897 :: 1.3730
# 	 	 accuracy (train :: test): 57.3% :: 57.1%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 60.1%
#
# iteration 4_300  time: 19.9 seconds
# 	 	 loss(train :: test): 1.3078 :: 1.3816
# 	 	 accuracy (train :: test): 59.0% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 60.1%
#
# iteration 4_400  time: 20.2 seconds
# 	 	 loss(train :: test): 1.4230 :: 1.3844
# 	 	 accuracy (train :: test): 56.0% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.6%
#
# iteration 4_500  time: 20.5 seconds
# 	 	 loss(train :: test): 1.4088 :: 1.3682
# 	 	 accuracy (train :: test): 55.5% :: 57.1%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 60.7%
#
# iteration 4_600  time: 20.9 seconds
# 	 	 loss(train :: test): 1.3656 :: 1.3972
# 	 	 accuracy (train :: test): 57.1% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 58.8%
#
# iteration 4_700  time: 21.2 seconds
# 	 	 loss(train :: test): 1.3768 :: 1.3899
# 	 	 accuracy (train :: test): 56.6% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 58.4%
#
# iteration 4_800  time: 21.5 seconds
# 	 	 loss(train :: test): 1.4461 :: 1.3883
# 	 	 accuracy (train :: test): 55.6% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 58.9%
#
# iteration 4_900  time: 21.8 seconds
# 	 	 loss(train :: test): 1.4002 :: 1.3757
# 	 	 accuracy (train :: test): 56.0% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 59.7%
#
# iteration 4_999  time: 22.1 seconds
# 	 	 loss(train :: test): 1.3678 :: 1.4150
# 	 	 accuracy (train :: test): 56.8% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 55.2%
#
#
# ============================================================
# Training with label_smoothing = 0.05
# ============================================================
#
# iteration 0  time: 6.1 seconds
# 	 	 loss(train :: test): 1.7026 :: 1.7123
# 	 	 accuracy (train :: test): 57.0% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.3%
#
# iteration 100  time: 6.5 seconds
# 	 	 loss(train :: test): 1.6133 :: 1.6384
# 	 	 accuracy (train :: test): 56.6% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 61.3%
#
# iteration 200  time: 6.8 seconds
# 	 	 loss(train :: test): 1.6049 :: 1.6486
# 	 	 accuracy (train :: test): 56.9% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 58.1%
#
# iteration 300  time: 7.1 seconds
# 	 	 loss(train :: test): 1.6712 :: 1.6291
# 	 	 accuracy (train :: test): 54.3% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 57.1%
#
# iteration 400  time: 7.4 seconds
# 	 	 loss(train :: test): 1.5632 :: 1.6226
# 	 	 accuracy (train :: test): 57.0% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 58.3%
#
# iteration 500  time: 7.7 seconds
# 	 	 loss(train :: test): 1.5690 :: 1.6328
# 	 	 accuracy (train :: test): 56.9% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 59.9%
#
# iteration 600  time: 8.0 seconds
# 	 	 loss(train :: test): 1.6434 :: 1.6289
# 	 	 accuracy (train :: test): 55.2% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 57.1%
#
# iteration 700  time: 8.3 seconds
# 	 	 loss(train :: test): 1.6333 :: 1.6278
# 	 	 accuracy (train :: test): 55.4% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 58.6%
#
# iteration 800  time: 8.6 seconds
# 	 	 loss(train :: test): 1.6100 :: 1.6260
# 	 	 accuracy (train :: test): 56.3% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 59.5%
#
# iteration 900  time: 8.9 seconds
# 	 	 loss(train :: test): 1.6170 :: 1.6174
# 	 	 accuracy (train :: test): 55.6% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.6%
#
# iteration 1_000  time: 9.2 seconds
# 	 	 loss(train :: test): 1.6114 :: 1.6289
# 	 	 accuracy (train :: test): 56.6% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 59.6%
#
# iteration 1_100  time: 9.6 seconds
# 	 	 loss(train :: test): 1.5717 :: 1.6270
# 	 	 accuracy (train :: test): 57.3% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 61.1%
#
# iteration 1_200  time: 9.9 seconds
# 	 	 loss(train :: test): 1.5860 :: 1.6041
# 	 	 accuracy (train :: test): 56.4% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 57.4%
#
# iteration 1_300  time: 10.2 seconds
# 	 	 loss(train :: test): 1.5962 :: 1.6229
# 	 	 accuracy (train :: test): 56.8% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 59.6%
#
# iteration 1_400  time: 10.5 seconds
# 	 	 loss(train :: test): 1.5920 :: 1.6126
# 	 	 accuracy (train :: test): 56.1% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.5%
#
# iteration 1_500  time: 10.8 seconds
# 	 	 loss(train :: test): 1.6202 :: 1.6154
# 	 	 accuracy (train :: test): 55.8% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 60.1%
#
# iteration 1_600  time: 11.1 seconds
# 	 	 loss(train :: test): 1.6039 :: 1.6199
# 	 	 accuracy (train :: test): 56.5% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 59.6%
#
# iteration 1_700  time: 11.4 seconds
# 	 	 loss(train :: test): 1.5955 :: 1.5873
# 	 	 accuracy (train :: test): 56.0% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 59.0%
#
# iteration 1_800  time: 11.7 seconds
# 	 	 loss(train :: test): 1.6111 :: 1.6173
# 	 	 accuracy (train :: test): 56.3% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.6%
#
# iteration 1_900  time: 12.0 seconds
# 	 	 loss(train :: test): 1.5812 :: 1.6287
# 	 	 accuracy (train :: test): 57.0% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 60.4%
#
# iteration 2_000  time: 12.3 seconds
# 	 	 loss(train :: test): 1.5553 :: 1.6214
# 	 	 accuracy (train :: test): 58.0% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 58.8%
#
# iteration 2_100  time: 12.6 seconds
# 	 	 loss(train :: test): 1.5532 :: 1.5989
# 	 	 accuracy (train :: test): 57.6% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 59.4%
#
# iteration 2_200  time: 12.9 seconds
# 	 	 loss(train :: test): 1.6284 :: 1.6040
# 	 	 accuracy (train :: test): 55.9% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 58.4%
#
# iteration 2_300  time: 13.2 seconds
# 	 	 loss(train :: test): 1.6013 :: 1.6191
# 	 	 accuracy (train :: test): 56.3% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 57.2%
#
# iteration 2_400  time: 13.6 seconds
# 	 	 loss(train :: test): 1.5760 :: 1.6173
# 	 	 accuracy (train :: test): 56.6% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 58.2%
#
# iteration 2_500  time: 13.9 seconds
# 	 	 loss(train :: test): 1.6258 :: 1.6148
# 	 	 accuracy (train :: test): 55.9% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 58.3%
#
# iteration 2_600  time: 14.2 seconds
# 	 	 loss(train :: test): 1.6027 :: 1.5974
# 	 	 accuracy (train :: test): 56.6% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.9%
#
# iteration 2_700  time: 14.5 seconds
# 	 	 loss(train :: test): 1.5458 :: 1.6063
# 	 	 accuracy (train :: test): 58.4% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 61.6%
#
# iteration 2_800  time: 14.8 seconds
# 	 	 loss(train :: test): 1.5785 :: 1.5960
# 	 	 accuracy (train :: test): 57.1% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 61.5%
#
# iteration 2_900  time: 15.1 seconds
# 	 	 loss(train :: test): 1.5877 :: 1.6127
# 	 	 accuracy (train :: test): 56.6% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 58.3%
#
# iteration 3_000  time: 15.4 seconds
# 	 	 loss(train :: test): 1.5468 :: 1.6113
# 	 	 accuracy (train :: test): 58.5% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 57.3%
#
# iteration 3_100  time: 15.8 seconds
# 	 	 loss(train :: test): 1.6000 :: 1.6094
# 	 	 accuracy (train :: test): 56.3% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.3%
#
# iteration 3_200  time: 16.1 seconds
# 	 	 loss(train :: test): 1.5439 :: 1.5886
# 	 	 accuracy (train :: test): 58.5% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 62.7%
#
# iteration 3_300  time: 16.4 seconds
# 	 	 loss(train :: test): 1.5857 :: 1.5884
# 	 	 accuracy (train :: test): 57.9% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 59.4%
#
# iteration 3_400  time: 16.7 seconds
# 	 	 loss(train :: test): 1.5581 :: 1.6097
# 	 	 accuracy (train :: test): 57.9% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 59.2%
#
# iteration 3_500  time: 17.0 seconds
# 	 	 loss(train :: test): 1.5752 :: 1.5958
# 	 	 accuracy (train :: test): 58.1% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 58.1%
#
# iteration 3_600  time: 17.3 seconds
# 	 	 loss(train :: test): 1.5958 :: 1.5942
# 	 	 accuracy (train :: test): 55.9% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 59.8%
#
# iteration 3_700  time: 17.6 seconds
# 	 	 loss(train :: test): 1.5837 :: 1.5948
# 	 	 accuracy (train :: test): 57.3% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.7%
#
# iteration 3_800  time: 17.9 seconds
# 	 	 loss(train :: test): 1.5927 :: 1.5878
# 	 	 accuracy (train :: test): 56.9% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 60.6%
#
# iteration 3_900  time: 18.2 seconds
# 	 	 loss(train :: test): 1.5851 :: 1.6052
# 	 	 accuracy (train :: test): 57.2% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.3%
#
# iteration 4_000  time: 18.5 seconds
# 	 	 loss(train :: test): 1.5467 :: 1.5972
# 	 	 accuracy (train :: test): 58.4% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.8%
#
# iteration 4_100  time: 18.8 seconds
# 	 	 loss(train :: test): 1.5758 :: 1.5844
# 	 	 accuracy (train :: test): 57.5% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 59.5%
#
# iteration 4_200  time: 19.1 seconds
# 	 	 loss(train :: test): 1.6015 :: 1.6132
# 	 	 accuracy (train :: test): 56.5% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 59.7%
#
# iteration 4_300  time: 19.4 seconds
# 	 	 loss(train :: test): 1.6100 :: 1.6043
# 	 	 accuracy (train :: test): 56.4% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 56.4%
#
# iteration 4_400  time: 19.7 seconds
# 	 	 loss(train :: test): 1.5089 :: 1.6084
# 	 	 accuracy (train :: test): 59.7% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 59.4%
#
# iteration 4_500  time: 20.0 seconds
# 	 	 loss(train :: test): 1.5843 :: 1.5769
# 	 	 accuracy (train :: test): 57.0% :: 57.2%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 59.2%
#
# iteration 4_600  time: 20.4 seconds
# 	 	 loss(train :: test): 1.5925 :: 1.6063
# 	 	 accuracy (train :: test): 56.2% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 58.9%
#
# iteration 4_700  time: 20.7 seconds
# 	 	 loss(train :: test): 1.5831 :: 1.5930
# 	 	 accuracy (train :: test): 57.1% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 58.4%
#
# iteration 4_800  time: 21.0 seconds
# 	 	 loss(train :: test): 1.5960 :: 1.6001
# 	 	 accuracy (train :: test): 57.2% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 59.2%
#
# iteration 4_900  time: 21.3 seconds
# 	 	 loss(train :: test): 1.5735 :: 1.5891
# 	 	 accuracy (train :: test): 57.6% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 68.8% :: 60.9%
#
# iteration 4_999  time: 21.6 seconds
# 	 	 loss(train :: test): 1.5864 :: 1.5897
# 	 	 accuracy (train :: test): 56.6% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.6%
#
#
# ============================================================
# Training with label_smoothing = 0.1
# ============================================================
#
# iteration 0  time: 5.9 seconds
# 	 	 loss(train :: test): 2.0183 :: 1.9647
# 	 	 accuracy (train :: test): 56.9% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 53.7%
#
# iteration 100  time: 6.2 seconds
# 	 	 loss(train :: test): 1.8051 :: 1.8118
# 	 	 accuracy (train :: test): 55.5% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 58.1%
#
# iteration 200  time: 6.5 seconds
# 	 	 loss(train :: test): 1.7729 :: 1.8046
# 	 	 accuracy (train :: test): 56.8% :: 55.3%
# 	 	 accuracy (last character) (train :: test): 69.5% :: 57.2%
#
# iteration 300  time: 6.8 seconds
# 	 	 loss(train :: test): 1.7993 :: 1.7996
# 	 	 accuracy (train :: test): 55.7% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 56.4%
#
# iteration 400  time: 7.2 seconds
# 	 	 loss(train :: test): 1.7820 :: 1.7992
# 	 	 accuracy (train :: test): 56.5% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.1%
#
# iteration 500  time: 7.5 seconds
# 	 	 loss(train :: test): 1.7453 :: 1.7906
# 	 	 accuracy (train :: test): 57.7% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 56.7%
#
# iteration 600  time: 7.8 seconds
# 	 	 loss(train :: test): 1.7419 :: 1.7790
# 	 	 accuracy (train :: test): 58.1% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.7%
#
# iteration 700  time: 8.1 seconds
# 	 	 loss(train :: test): 1.8090 :: 1.7737
# 	 	 accuracy (train :: test): 54.6% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.4%
#
# iteration 800  time: 8.4 seconds
# 	 	 loss(train :: test): 1.7641 :: 1.8158
# 	 	 accuracy (train :: test): 56.5% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 56.5%
#
# iteration 900  time: 8.7 seconds
# 	 	 loss(train :: test): 1.7343 :: 1.7920
# 	 	 accuracy (train :: test): 58.2% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 57.5%
#
# iteration 1_000  time: 9.0 seconds
# 	 	 loss(train :: test): 1.8200 :: 1.8062
# 	 	 accuracy (train :: test): 55.0% :: 55.3%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 59.0%
#
# iteration 1_100  time: 9.3 seconds
# 	 	 loss(train :: test): 1.8114 :: 1.7800
# 	 	 accuracy (train :: test): 55.2% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 58.3%
#
# iteration 1_200  time: 9.6 seconds
# 	 	 loss(train :: test): 1.7763 :: 1.7854
# 	 	 accuracy (train :: test): 56.4% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 58.7%
#
# iteration 1_300  time: 9.9 seconds
# 	 	 loss(train :: test): 1.7700 :: 1.7929
# 	 	 accuracy (train :: test): 56.9% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 57.9%
#
# iteration 1_400  time: 10.2 seconds
# 	 	 loss(train :: test): 1.8067 :: 1.7781
# 	 	 accuracy (train :: test): 54.2% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 58.5%
#
# iteration 1_500  time: 10.5 seconds
# 	 	 loss(train :: test): 1.7697 :: 1.7839
# 	 	 accuracy (train :: test): 57.3% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 56.3%
#
# iteration 1_600  time: 10.9 seconds
# 	 	 loss(train :: test): 1.7992 :: 1.7979
# 	 	 accuracy (train :: test): 55.8% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 57.9%
#
# iteration 1_700  time: 11.2 seconds
# 	 	 loss(train :: test): 1.7848 :: 1.7851
# 	 	 accuracy (train :: test): 56.9% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 60.5%
#
# iteration 1_800  time: 11.5 seconds
# 	 	 loss(train :: test): 1.7588 :: 1.7869
# 	 	 accuracy (train :: test): 57.0% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 58.7%
#
# iteration 1_900  time: 11.8 seconds
# 	 	 loss(train :: test): 1.7595 :: 1.7858
# 	 	 accuracy (train :: test): 56.4% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 59.0%
#
# iteration 2_000  time: 12.1 seconds
# 	 	 loss(train :: test): 1.8140 :: 1.7787
# 	 	 accuracy (train :: test): 55.4% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 56.3%
#
# iteration 2_100  time: 12.4 seconds
# 	 	 loss(train :: test): 1.7783 :: 1.7847
# 	 	 accuracy (train :: test): 55.7% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 61.5%
#
# iteration 2_200  time: 12.7 seconds
# 	 	 loss(train :: test): 1.7750 :: 1.7656
# 	 	 accuracy (train :: test): 56.6% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 56.8%
#
# iteration 2_300  time: 13.0 seconds
# 	 	 loss(train :: test): 1.7804 :: 1.7922
# 	 	 accuracy (train :: test): 56.2% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 57.3%
#
# iteration 2_400  time: 13.3 seconds
# 	 	 loss(train :: test): 1.7818 :: 1.7625
# 	 	 accuracy (train :: test): 56.0% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 59.7%
#
# iteration 2_500  time: 13.6 seconds
# 	 	 loss(train :: test): 1.7581 :: 1.7863
# 	 	 accuracy (train :: test): 56.9% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 58.7%
#
# iteration 2_600  time: 14.0 seconds
# 	 	 loss(train :: test): 1.7421 :: 1.7854
# 	 	 accuracy (train :: test): 57.7% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 57.7%
#
# iteration 2_700  time: 14.3 seconds
# 	 	 loss(train :: test): 1.7944 :: 1.7605
# 	 	 accuracy (train :: test): 56.3% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 59.2%
#
# iteration 2_800  time: 14.6 seconds
# 	 	 loss(train :: test): 1.7179 :: 1.7785
# 	 	 accuracy (train :: test): 57.7% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.2%
#
# iteration 2_900  time: 14.9 seconds
# 	 	 loss(train :: test): 1.7652 :: 1.7819
# 	 	 accuracy (train :: test): 57.1% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 59.9%
#
# iteration 3_000  time: 15.2 seconds
# 	 	 loss(train :: test): 1.7531 :: 1.7719
# 	 	 accuracy (train :: test): 57.1% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 56.7%
#
# iteration 3_100  time: 15.5 seconds
# 	 	 loss(train :: test): 1.7513 :: 1.7828
# 	 	 accuracy (train :: test): 56.9% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 56.3%
#
# iteration 3_200  time: 15.8 seconds
# 	 	 loss(train :: test): 1.7680 :: 1.7651
# 	 	 accuracy (train :: test): 57.3% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 59.8%
#
# iteration 3_300  time: 16.1 seconds
# 	 	 loss(train :: test): 1.7853 :: 1.7841
# 	 	 accuracy (train :: test): 56.7% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 59.0%
#
# iteration 3_400  time: 16.4 seconds
# 	 	 loss(train :: test): 1.7475 :: 1.7747
# 	 	 accuracy (train :: test): 56.8% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 59.7%
#
# iteration 3_500  time: 16.7 seconds
# 	 	 loss(train :: test): 1.7459 :: 1.7785
# 	 	 accuracy (train :: test): 57.5% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.3%
#
# iteration 3_600  time: 17.0 seconds
# 	 	 loss(train :: test): 1.7463 :: 1.7701
# 	 	 accuracy (train :: test): 57.2% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 65.6% :: 58.3%
#
# iteration 3_700  time: 17.3 seconds
# 	 	 loss(train :: test): 1.7593 :: 1.7693
# 	 	 accuracy (train :: test): 57.4% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 58.1%
#
# iteration 3_800  time: 17.7 seconds
# 	 	 loss(train :: test): 1.7076 :: 1.7718
# 	 	 accuracy (train :: test): 59.5% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 60.9%
#
# iteration 3_900  time: 18.0 seconds
# 	 	 loss(train :: test): 1.7127 :: 1.7697
# 	 	 accuracy (train :: test): 58.4% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 56.2%
#
# iteration 4_000  time: 18.3 seconds
# 	 	 loss(train :: test): 1.7681 :: 1.7639
# 	 	 accuracy (train :: test): 56.9% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 60.0%
#
# iteration 4_100  time: 18.6 seconds
# 	 	 loss(train :: test): 1.7653 :: 1.7775
# 	 	 accuracy (train :: test): 56.3% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.7%
#
# iteration 4_200  time: 18.9 seconds
# 	 	 loss(train :: test): 1.7588 :: 1.7523
# 	 	 accuracy (train :: test): 57.0% :: 57.4%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.7%
#
# iteration 4_300  time: 19.2 seconds
# 	 	 loss(train :: test): 1.7614 :: 1.7679
# 	 	 accuracy (train :: test): 56.0% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.3%
#
# iteration 4_400  time: 19.5 seconds
# 	 	 loss(train :: test): 1.7417 :: 1.7721
# 	 	 accuracy (train :: test): 58.1% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 59.7%
#
# iteration 4_500  time: 19.8 seconds
# 	 	 loss(train :: test): 1.7942 :: 1.7667
# 	 	 accuracy (train :: test): 55.9% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 58.9%
#
# iteration 4_600  time: 20.1 seconds
# 	 	 loss(train :: test): 1.7289 :: 1.7906
# 	 	 accuracy (train :: test): 57.9% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 68.0% :: 58.0%
#
# iteration 4_700  time: 20.4 seconds
# 	 	 loss(train :: test): 1.7105 :: 1.7669
# 	 	 accuracy (train :: test): 59.0% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 57.6%
#
# iteration 4_800  time: 20.7 seconds
# 	 	 loss(train :: test): 1.7644 :: 1.7661
# 	 	 accuracy (train :: test): 56.2% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 59.8%
#
# iteration 4_900  time: 21.0 seconds
# 	 	 loss(train :: test): 1.7700 :: 1.7416
# 	 	 accuracy (train :: test): 56.0% :: 57.3%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 59.8%
#
# iteration 4_999  time: 21.4 seconds
# 	 	 loss(train :: test): 1.7379 :: 1.7635
# 	 	 accuracy (train :: test): 56.9% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 59.9%
#
#
# ============================================================
# Training with label_smoothing = 0.2
# ============================================================
#
# iteration 0  time: 6.1 seconds
# 	 	 loss(train :: test): 2.6602 :: 2.3671
# 	 	 accuracy (train :: test): 56.8% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 54.3%
#
# iteration 100  time: 6.4 seconds
# 	 	 loss(train :: test): 2.0670 :: 2.0982
# 	 	 accuracy (train :: test): 56.4% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 57.4%
#
# iteration 200  time: 6.8 seconds
# 	 	 loss(train :: test): 2.0911 :: 2.0832
# 	 	 accuracy (train :: test): 55.8% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 56.0%
#
# iteration 300  time: 7.1 seconds
# 	 	 loss(train :: test): 2.1066 :: 2.1019
# 	 	 accuracy (train :: test): 55.4% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.0%
#
# iteration 400  time: 7.4 seconds
# 	 	 loss(train :: test): 2.1049 :: 2.0829
# 	 	 accuracy (train :: test): 54.8% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.8%
#
# iteration 500  time: 7.8 seconds
# 	 	 loss(train :: test): 2.0676 :: 2.0860
# 	 	 accuracy (train :: test): 56.3% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 58.0%
#
# iteration 600  time: 8.0 seconds
# 	 	 loss(train :: test): 2.0796 :: 2.0849
# 	 	 accuracy (train :: test): 56.3% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 59.0%
#
# iteration 700  time: 8.3 seconds
# 	 	 loss(train :: test): 2.1118 :: 2.0846
# 	 	 accuracy (train :: test): 55.2% :: 55.6%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 58.9%
#
# iteration 800  time: 8.6 seconds
# 	 	 loss(train :: test): 2.1080 :: 2.0842
# 	 	 accuracy (train :: test): 55.1% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 55.7%
#
# iteration 900  time: 8.9 seconds
# 	 	 loss(train :: test): 2.0838 :: 2.0845
# 	 	 accuracy (train :: test): 55.7% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.1%
#
# iteration 1_000  time: 9.2 seconds
# 	 	 loss(train :: test): 2.0878 :: 2.0800
# 	 	 accuracy (train :: test): 56.0% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.4%
#
# iteration 1_100  time: 9.4 seconds
# 	 	 loss(train :: test): 2.0895 :: 2.0870
# 	 	 accuracy (train :: test): 56.0% :: 55.8%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 58.3%
#
# iteration 1_200  time: 9.7 seconds
# 	 	 loss(train :: test): 2.0856 :: 2.0659
# 	 	 accuracy (train :: test): 55.7% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 56.8%
#
# iteration 1_300  time: 10.0 seconds
# 	 	 loss(train :: test): 2.0941 :: 2.0779
# 	 	 accuracy (train :: test): 55.7% :: 56.1%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 61.2%
#
# iteration 1_400  time: 10.2 seconds
# 	 	 loss(train :: test): 2.0580 :: 2.0750
# 	 	 accuracy (train :: test): 57.3% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 58.6%
#
# iteration 1_500  time: 10.5 seconds
# 	 	 loss(train :: test): 2.0380 :: 2.0698
# 	 	 accuracy (train :: test): 57.9% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.3%
#
# iteration 1_600  time: 10.8 seconds
# 	 	 loss(train :: test): 2.0956 :: 2.0720
# 	 	 accuracy (train :: test): 55.8% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 59.4%
#
# iteration 1_700  time: 11.1 seconds
# 	 	 loss(train :: test): 2.0989 :: 2.0750
# 	 	 accuracy (train :: test): 55.8% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.8%
#
# iteration 1_800  time: 11.4 seconds
# 	 	 loss(train :: test): 2.0719 :: 2.0683
# 	 	 accuracy (train :: test): 56.6% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 57.6%
#
# iteration 1_900  time: 11.6 seconds
# 	 	 loss(train :: test): 2.0361 :: 2.0720
# 	 	 accuracy (train :: test): 57.5% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 59.0%
#
# iteration 2_000  time: 11.9 seconds
# 	 	 loss(train :: test): 2.0509 :: 2.0739
# 	 	 accuracy (train :: test): 56.6% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 60.7%
#
# iteration 2_100  time: 12.2 seconds
# 	 	 loss(train :: test): 2.0711 :: 2.0769
# 	 	 accuracy (train :: test): 56.6% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 58.4%
#
# iteration 2_200  time: 12.5 seconds
# 	 	 loss(train :: test): 2.0839 :: 2.0774
# 	 	 accuracy (train :: test): 56.1% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 58.0%
#
# iteration 2_300  time: 12.8 seconds
# 	 	 loss(train :: test): 2.0705 :: 2.0687
# 	 	 accuracy (train :: test): 57.2% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 59.0%
#
# iteration 2_400  time: 13.0 seconds
# 	 	 loss(train :: test): 2.0567 :: 2.0597
# 	 	 accuracy (train :: test): 56.3% :: 57.1%
# 	 	 accuracy (last character) (train :: test): 66.4% :: 60.4%
#
# iteration 2_500  time: 13.3 seconds
# 	 	 loss(train :: test): 2.0583 :: 2.0830
# 	 	 accuracy (train :: test): 57.6% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 59.3%
#
# iteration 2_600  time: 13.6 seconds
# 	 	 loss(train :: test): 2.0511 :: 2.0702
# 	 	 accuracy (train :: test): 57.1% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 59.8%
#
# iteration 2_700  time: 14.0 seconds
# 	 	 loss(train :: test): 2.0367 :: 2.0732
# 	 	 accuracy (train :: test): 57.7% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 57.1%
#
# iteration 2_800  time: 14.3 seconds
# 	 	 loss(train :: test): 2.0207 :: 2.0705
# 	 	 accuracy (train :: test): 59.2% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.6%
#
# iteration 2_900  time: 14.6 seconds
# 	 	 loss(train :: test): 2.0469 :: 2.0668
# 	 	 accuracy (train :: test): 57.5% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 62.3%
#
# iteration 3_000  time: 14.9 seconds
# 	 	 loss(train :: test): 2.0286 :: 2.0730
# 	 	 accuracy (train :: test): 57.1% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.4%
#
# iteration 3_100  time: 15.2 seconds
# 	 	 loss(train :: test): 2.0510 :: 2.0667
# 	 	 accuracy (train :: test): 57.2% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 57.4%
#
# iteration 3_200  time: 15.5 seconds
# 	 	 loss(train :: test): 2.0474 :: 2.0689
# 	 	 accuracy (train :: test): 57.3% :: 56.3%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 56.2%
#
# iteration 3_300  time: 15.8 seconds
# 	 	 loss(train :: test): 2.0976 :: 2.0502
# 	 	 accuracy (train :: test): 54.6% :: 57.1%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 60.2%
#
# iteration 3_400  time: 16.1 seconds
# 	 	 loss(train :: test): 2.0195 :: 2.0750
# 	 	 accuracy (train :: test): 58.1% :: 56.4%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 59.5%
#
# iteration 3_500  time: 16.4 seconds
# 	 	 loss(train :: test): 2.0710 :: 2.0650
# 	 	 accuracy (train :: test): 55.8% :: 56.5%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 57.9%
#
# iteration 3_600  time: 16.7 seconds
# 	 	 loss(train :: test): 2.0501 :: 2.0599
# 	 	 accuracy (train :: test): 57.1% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.9%
#
# iteration 3_700  time: 17.0 seconds
# 	 	 loss(train :: test): 2.0554 :: 2.0617
# 	 	 accuracy (train :: test): 57.0% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.6%
#
# iteration 3_800  time: 17.3 seconds
# 	 	 loss(train :: test): 2.0436 :: 2.0530
# 	 	 accuracy (train :: test): 57.6% :: 57.1%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 59.9%
#
# iteration 3_900  time: 17.7 seconds
# 	 	 loss(train :: test): 2.0784 :: 2.0753
# 	 	 accuracy (train :: test): 56.0% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 56.8%
#
# iteration 4_000  time: 18.0 seconds
# 	 	 loss(train :: test): 2.0495 :: 2.0557
# 	 	 accuracy (train :: test): 57.5% :: 56.8%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.2%
#
# iteration 4_100  time: 18.3 seconds
# 	 	 loss(train :: test): 2.0466 :: 2.0572
# 	 	 accuracy (train :: test): 57.4% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.1%
#
# iteration 4_200  time: 18.6 seconds
# 	 	 loss(train :: test): 2.0366 :: 2.0746
# 	 	 accuracy (train :: test): 57.7% :: 56.2%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 56.4%
#
# iteration 4_300  time: 18.9 seconds
# 	 	 loss(train :: test): 2.0468 :: 2.0504
# 	 	 accuracy (train :: test): 57.4% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 59.6%
#
# iteration 4_400  time: 19.2 seconds
# 	 	 loss(train :: test): 2.0791 :: 2.0739
# 	 	 accuracy (train :: test): 55.6% :: 56.0%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.7%
#
# iteration 4_500  time: 19.5 seconds
# 	 	 loss(train :: test): 2.0338 :: 2.0566
# 	 	 accuracy (train :: test): 57.5% :: 57.0%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 60.1%
#
# iteration 4_600  time: 19.8 seconds
# 	 	 loss(train :: test): 2.0624 :: 2.0659
# 	 	 accuracy (train :: test): 57.3% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 58.7%
#
# iteration 4_700  time: 20.1 seconds
# 	 	 loss(train :: test): 2.0760 :: 2.0665
# 	 	 accuracy (train :: test): 56.6% :: 56.6%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 60.3%
#
# iteration 4_800  time: 20.4 seconds
# 	 	 loss(train :: test): 2.0611 :: 2.0524
# 	 	 accuracy (train :: test): 56.5% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 58.7%
#
# iteration 4_900  time: 20.7 seconds
# 	 	 loss(train :: test): 2.0628 :: 2.0551
# 	 	 accuracy (train :: test): 57.1% :: 56.9%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.0%
#
# iteration 4_999  time: 21.0 seconds
# 	 	 loss(train :: test): 2.0377 :: 2.0553
# 	 	 accuracy (train :: test): 57.5% :: 56.7%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 59.2%

# %%
fig1 = plot_label_smoothing_comparison(results)
plt.show()


fig2 = plot_final_comparison(results)
plt.show()


print_summary(results)
# Out:
# ================================================================================
# FINAL RESULTS SUMMARY
# ================================================================================
# Label Smoothing      Test Loss       Test Acc (%)    Last Token Acc (%)
# --------------------------------------------------------------------------------
# 0.00                 1.4150          55.98           55.18
# 0.05                 1.5897          56.82           58.59
# 0.10                 1.7635          56.62           59.86
# 0.20                 2.0553          56.74           59.18

# %% [markdown]
# ### Tempeature scaling
#
# - temperature = 1.0 - baseline (no scaling)
# - temperature = 0.8 - sharper, more confident predictions
# - temperature = 1.2 - softer, less confident predictions
# - temperature = 0.5 - very sharp (risk of overconfidence)

# %%
# Remove @jax.jit or add static_argnames
from functools import partial

@partial(jax.jit, static_argnames=['temperature'])
def loss_and_metrics(logits, targets, temperature=1.0):
    """Compute cross-entropy loss and accuracy.

    Args:
      logits: (B, T, V) float array of unnormalized scores.
      targets: (B, T) integer array with ground-truth class ids.
      temperature: Float > 0. Scales logits before softmax.
                   < 1.0 = sharper predictions (more confident)
                   > 1.0 = softer predictions (less confident)

    Returns:
      loss: scalar average cross-entropy.
      metrics: dict with keys "loss", "acc", and "acc_last".
    """
    vocab = logits.shape[-1]
    
    # Apply temperature scaling to logits
    scaled_logits = logits / temperature
    
    flat_logits = scaled_logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)

    # Compute cross-entropy
    per_pos = optax.softmax_cross_entropy_with_integer_labels(flat_logits, flat_targets)
    loss = per_pos.mean()

    # Predictions and accuracy (use scaled logits)
    preds = jnp.argmax(scaled_logits, axis=-1)
    is_match = preds == targets
    acc_all = jnp.mean(is_match.astype(jnp.float32))
    acc_last = jnp.mean(is_match[:, -1].astype(jnp.float32))

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %%
def train_step(params, opt_state, x, y, tx, temperature=1.0):
    """Single optimization step using optax optimizer.

    Args:
      params: pytree of model parameters.
      opt_state: optax optimizer state corresponding to `params`.
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
      tx: optax.GradientTransformation (already initialized).
      temperature: Float > 0 for temperature scaling.

    Returns:
      new_params: updated parameters after one gradient step.
      new_opt_state: updated optimizer state.
      metrics: dict of scalar metrics (loss, acc).
    """
    def loss_fn(params):
        logits = model.apply({"params": params}, x)
        loss, metrics = loss_and_metrics(logits, y, temperature=temperature)
        return loss, metrics

    # compute gradients (loss is scalar, metrics is auxiliary)
    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)

    # optax update: compute parameter updates and new optimizer state
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    return new_params, new_opt_state, metrics

# jit: mark both tx and temperature as static
train_step = jax.jit(train_step, static_argnames=("tx", "temperature"))

# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# define optax optimizer
learning_rate = 0.001
# Create Adam optimizer (Optax)
tx = optax.adam(learning_rate=learning_rate)
# Initialize optimizer state for current params
opt_state = tx.init(params)
print(f"Initialized optimizer: Adam lr={learning_rate}")
# Out:
# Initialized optimizer: Adam lr=0.001

# %%
import time

params_init = params

# Define temperature values to test
temperature_values = [0.5, 0.8, 1.0, 1.2]

results = {}

for temp_val in temperature_values:
    print(f"\n{'='*60}")
    print(f"Training with temperature = {temp_val}")
    print(f"{'='*60}\n")
    
    # Reset parameters for each run
    params = params_init  # Your initial parameters
    opt_state = tx.init(params)
    
    loss_history = []
    time_history = []
    loss_test_history = []
    acc_test_history = []
    acc_last_test_history = []
    time_test_history = []
    time_start = time.time()
    
    niter = 5000
    B, T = 128, 32
    
    for it in range(niter):
        batch = get_batch(train_text_int, B, T)
        x, y = batch[0], batch[1]
        
        # Train with specific temperature
        params, opt_state, metrics = train_step(params, opt_state, x, y, tx, temperature=temp_val)
        
        loss_history.append(float(metrics['loss']))
        time_history.append(time.time() - time_start)
        
        if it % (niter // 50) == 0 or it == niter - 1:
            time_since_start = time.time() - time_start
            
            # Test evaluation
            B_test, T_test = 1024, 32
            test_batch = get_batch(test_text_int, B_test, T_test)
            test_x, test_y = test_batch[0], test_batch[1]
            test_logits = model.apply({"params": params}, test_x)
            
            # Use same temperature for test evaluation
            test_loss, test_metrics = loss_and_metrics(test_logits, test_y, temperature=temp_val)
            
            loss_test_history.append(float(test_loss))
            acc_test_history.append(float(test_metrics['acc']))
            acc_last_test_history.append(float(test_metrics['acc_last']))
            time_test_history.append(time_since_start)
            
            print(f"iteration {it:_}  time: {time_since_start:.1f} seconds")
            print(f"\t \t loss(train :: test): {metrics['loss']:.4f} :: {test_loss:.4f}")
            print(f"\t \t accuracy (train :: test): {100*metrics['acc']:.1f}% :: {100*test_metrics['acc']:.1f}%")
            print(f"\t \t accuracy (last character) (train :: test): {100*metrics['acc_last']:.1f}% :: {100*test_metrics['acc_last']:.1f}%")
            print()
    
    results[temp_val] = {
        'loss_train': loss_history,
        'loss_test': loss_test_history,
        'acc_test': acc_test_history,
        'acc_last_test': acc_last_test_history,
        'time_train': time_history,
        'time_test': time_test_history
    }
# Out:
# ============================================================
# Training with temperature = 0.5
# ============================================================
#
# iteration 0  time: 0.0 seconds
# 	 	 loss(train :: test): 5.6286 :: 4.8323
# 	 	 accuracy (train :: test): 2.2% :: 15.9%
# 	 	 accuracy (last character) (train :: test): 2.3% :: 16.8%
#
# iteration 100  time: 0.3 seconds
# 	 	 loss(train :: test): 2.3462 :: 2.3480
# 	 	 accuracy (train :: test): 27.5% :: 29.0%
# 	 	 accuracy (last character) (train :: test): 24.2% :: 28.1%
#
# iteration 200  time: 0.6 seconds
# 	 	 loss(train :: test): 2.1540 :: 2.1067
# 	 	 accuracy (train :: test): 34.8% :: 35.9%
# 	 	 accuracy (last character) (train :: test): 36.7% :: 35.7%
#
# iteration 300  time: 0.8 seconds
# 	 	 loss(train :: test): 1.9088 :: 1.9445
# 	 	 accuracy (train :: test): 42.5% :: 41.3%
# 	 	 accuracy (last character) (train :: test): 43.0% :: 42.1%
#
# iteration 400  time: 1.1 seconds
# 	 	 loss(train :: test): 1.8324 :: 1.8356
# 	 	 accuracy (train :: test): 44.5% :: 44.3%
# 	 	 accuracy (last character) (train :: test): 40.6% :: 44.3%
#
# iteration 500  time: 1.4 seconds
# 	 	 loss(train :: test): 1.8043 :: 1.7824
# 	 	 accuracy (train :: test): 45.8% :: 45.7%
# 	 	 accuracy (last character) (train :: test): 45.3% :: 48.4%
#
# iteration 600  time: 1.7 seconds
# 	 	 loss(train :: test): 1.7087 :: 1.7077
# 	 	 accuracy (train :: test): 48.2% :: 47.9%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 51.3%
#
# iteration 700  time: 2.0 seconds
# 	 	 loss(train :: test): 1.6458 :: 1.6808
# 	 	 accuracy (train :: test): 50.4% :: 48.3%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 49.9%
#
# iteration 800  time: 2.3 seconds
# 	 	 loss(train :: test): 1.6518 :: 1.6505
# 	 	 accuracy (train :: test): 50.3% :: 49.4%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 50.6%
#
# iteration 900  time: 2.7 seconds
# 	 	 loss(train :: test): 1.6805 :: 1.5987
# 	 	 accuracy (train :: test): 49.2% :: 50.5%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 53.5%
#
# iteration 1_000  time: 3.0 seconds
# 	 	 loss(train :: test): 1.5910 :: 1.6045
# 	 	 accuracy (train :: test): 51.5% :: 50.5%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 51.6%
#
# iteration 1_100  time: 3.3 seconds
# 	 	 loss(train :: test): 1.5682 :: 1.5868
# 	 	 accuracy (train :: test): 51.8% :: 51.2%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 53.6%
#
# iteration 1_200  time: 3.6 seconds
# 	 	 loss(train :: test): 1.6309 :: 1.5716
# 	 	 accuracy (train :: test): 49.7% :: 52.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 50.4%
#
# iteration 1_300  time: 3.9 seconds
# 	 	 loss(train :: test): 1.5666 :: 1.5844
# 	 	 accuracy (train :: test): 52.1% :: 51.5%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 53.3%
#
# iteration 1_400  time: 4.2 seconds
# 	 	 loss(train :: test): 1.5621 :: 1.5697
# 	 	 accuracy (train :: test): 51.6% :: 51.7%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 55.3%
#
# iteration 1_500  time: 4.6 seconds
# 	 	 loss(train :: test): 1.5192 :: 1.5490
# 	 	 accuracy (train :: test): 53.5% :: 52.5%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 55.8%
#
# iteration 1_600  time: 4.8 seconds
# 	 	 loss(train :: test): 1.5642 :: 1.5441
# 	 	 accuracy (train :: test): 52.3% :: 52.3%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 52.8%
#
# iteration 1_700  time: 5.1 seconds
# 	 	 loss(train :: test): 1.5259 :: 1.5300
# 	 	 accuracy (train :: test): 53.3% :: 53.0%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 52.0%
#
# iteration 1_800  time: 5.4 seconds
# 	 	 loss(train :: test): 1.5341 :: 1.5289
# 	 	 accuracy (train :: test): 52.3% :: 53.0%
# 	 	 accuracy (last character) (train :: test): 47.7% :: 56.3%
#
# iteration 1_900  time: 5.7 seconds
# 	 	 loss(train :: test): 1.5464 :: 1.5416
# 	 	 accuracy (train :: test): 52.4% :: 52.3%
# 	 	 accuracy (last character) (train :: test): 46.9% :: 54.4%
#
# iteration 2_000  time: 6.0 seconds
# 	 	 loss(train :: test): 1.5027 :: 1.5273
# 	 	 accuracy (train :: test): 52.5% :: 52.8%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 52.0%
#
# iteration 2_100  time: 6.2 seconds
# 	 	 loss(train :: test): 1.4399 :: 1.5189
# 	 	 accuracy (train :: test): 54.8% :: 53.2%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 53.5%
#
# iteration 2_200  time: 6.5 seconds
# 	 	 loss(train :: test): 1.5109 :: 1.4936
# 	 	 accuracy (train :: test): 53.4% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.1%
#
# iteration 2_300  time: 6.8 seconds
# 	 	 loss(train :: test): 1.5553 :: 1.5075
# 	 	 accuracy (train :: test): 52.8% :: 53.3%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 54.9%
#
# iteration 2_400  time: 7.1 seconds
# 	 	 loss(train :: test): 1.5224 :: 1.5014
# 	 	 accuracy (train :: test): 52.0% :: 53.6%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 55.3%
#
# iteration 2_500  time: 7.4 seconds
# 	 	 loss(train :: test): 1.4518 :: 1.4945
# 	 	 accuracy (train :: test): 55.2% :: 54.1%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 55.3%
#
# iteration 2_600  time: 7.6 seconds
# 	 	 loss(train :: test): 1.5064 :: 1.4962
# 	 	 accuracy (train :: test): 54.1% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 47.7% :: 54.2%
#
# iteration 2_700  time: 7.9 seconds
# 	 	 loss(train :: test): 1.5352 :: 1.4954
# 	 	 accuracy (train :: test): 51.9% :: 53.3%
# 	 	 accuracy (last character) (train :: test): 46.1% :: 54.7%
#
# iteration 2_800  time: 8.2 seconds
# 	 	 loss(train :: test): 1.4245 :: 1.4987
# 	 	 accuracy (train :: test): 55.3% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 56.7%
#
# iteration 2_900  time: 8.5 seconds
# 	 	 loss(train :: test): 1.4896 :: 1.4934
# 	 	 accuracy (train :: test): 53.5% :: 53.5%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 55.7%
#
# iteration 3_000  time: 8.7 seconds
# 	 	 loss(train :: test): 1.4915 :: 1.4724
# 	 	 accuracy (train :: test): 54.4% :: 54.2%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 58.2%
#
# iteration 3_100  time: 9.0 seconds
# 	 	 loss(train :: test): 1.4730 :: 1.4629
# 	 	 accuracy (train :: test): 54.2% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 57.6%
#
# iteration 3_200  time: 9.3 seconds
# 	 	 loss(train :: test): 1.5464 :: 1.4748
# 	 	 accuracy (train :: test): 52.4% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.1%
#
# iteration 3_300  time: 9.6 seconds
# 	 	 loss(train :: test): 1.4503 :: 1.4804
# 	 	 accuracy (train :: test): 54.1% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 55.3%
#
# iteration 3_400  time: 9.9 seconds
# 	 	 loss(train :: test): 1.4156 :: 1.4596
# 	 	 accuracy (train :: test): 55.0% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 56.2%
#
# iteration 3_500  time: 10.2 seconds
# 	 	 loss(train :: test): 1.4924 :: 1.4543
# 	 	 accuracy (train :: test): 53.7% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 58.1%
#
# iteration 3_600  time: 10.5 seconds
# 	 	 loss(train :: test): 1.4084 :: 1.4810
# 	 	 accuracy (train :: test): 55.7% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 53.2%
#
# iteration 3_700  time: 10.7 seconds
# 	 	 loss(train :: test): 1.4357 :: 1.4619
# 	 	 accuracy (train :: test): 55.5% :: 54.6%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 56.9%
#
# iteration 3_800  time: 11.0 seconds
# 	 	 loss(train :: test): 1.4589 :: 1.4674
# 	 	 accuracy (train :: test): 55.2% :: 54.6%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 56.1%
#
# iteration 3_900  time: 11.3 seconds
# 	 	 loss(train :: test): 1.4067 :: 1.4873
# 	 	 accuracy (train :: test): 54.8% :: 54.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 55.6%
#
# iteration 4_000  time: 11.6 seconds
# 	 	 loss(train :: test): 1.4469 :: 1.4664
# 	 	 accuracy (train :: test): 54.0% :: 54.2%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 55.0%
#
# iteration 4_100  time: 11.9 seconds
# 	 	 loss(train :: test): 1.4756 :: 1.4789
# 	 	 accuracy (train :: test): 54.1% :: 54.0%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 58.3%
#
# iteration 4_200  time: 12.2 seconds
# 	 	 loss(train :: test): 1.4452 :: 1.4433
# 	 	 accuracy (train :: test): 55.4% :: 54.7%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 59.1%
#
# iteration 4_300  time: 12.4 seconds
# 	 	 loss(train :: test): 1.4378 :: 1.4410
# 	 	 accuracy (train :: test): 55.9% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 59.0%
#
# iteration 4_400  time: 12.7 seconds
# 	 	 loss(train :: test): 1.4041 :: 1.4403
# 	 	 accuracy (train :: test): 55.6% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 58.2%
#
# iteration 4_500  time: 13.0 seconds
# 	 	 loss(train :: test): 1.4315 :: 1.4480
# 	 	 accuracy (train :: test): 55.2% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 58.7%
#
# iteration 4_600  time: 13.3 seconds
# 	 	 loss(train :: test): 1.5040 :: 1.4500
# 	 	 accuracy (train :: test): 53.2% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 56.4%
#
# iteration 4_700  time: 13.7 seconds
# 	 	 loss(train :: test): 1.4160 :: 1.4521
# 	 	 accuracy (train :: test): 56.0% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 55.2%
#
# iteration 4_800  time: 14.0 seconds
# 	 	 loss(train :: test): 1.4259 :: 1.4656
# 	 	 accuracy (train :: test): 55.2% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 57.7%
#
# iteration 4_900  time: 14.3 seconds
# 	 	 loss(train :: test): 1.4625 :: 1.4342
# 	 	 accuracy (train :: test): 54.9% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 57.5%
#
# iteration 4_999  time: 14.6 seconds
# 	 	 loss(train :: test): 1.3830 :: 1.4490
# 	 	 accuracy (train :: test): 57.2% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 56.9%
#
#
# ============================================================
# Training with temperature = 0.8
# ============================================================
#
# iteration 0  time: 5.8 seconds
# 	 	 loss(train :: test): 4.2834 :: 3.8276
# 	 	 accuracy (train :: test): 2.2% :: 17.4%
# 	 	 accuracy (last character) (train :: test): 6.2% :: 17.4%
#
# iteration 100  time: 8.1 seconds
# 	 	 loss(train :: test): 2.3424 :: 2.3060
# 	 	 accuracy (train :: test): 29.5% :: 29.9%
# 	 	 accuracy (last character) (train :: test): 26.6% :: 26.7%
#
# iteration 200  time: 8.6 seconds
# 	 	 loss(train :: test): 2.0160 :: 2.0080
# 	 	 accuracy (train :: test): 39.7% :: 39.0%
# 	 	 accuracy (last character) (train :: test): 35.9% :: 38.1%
#
# iteration 300  time: 9.1 seconds
# 	 	 loss(train :: test): 1.8800 :: 1.8909
# 	 	 accuracy (train :: test): 42.7% :: 42.3%
# 	 	 accuracy (last character) (train :: test): 46.9% :: 39.6%
#
# iteration 400  time: 9.5 seconds
# 	 	 loss(train :: test): 1.7809 :: 1.8081
# 	 	 accuracy (train :: test): 46.1% :: 44.8%
# 	 	 accuracy (last character) (train :: test): 43.8% :: 44.6%
#
# iteration 500  time: 10.0 seconds
# 	 	 loss(train :: test): 1.6838 :: 1.6997
# 	 	 accuracy (train :: test): 48.3% :: 48.1%
# 	 	 accuracy (last character) (train :: test): 46.1% :: 47.0%
#
# iteration 600  time: 10.4 seconds
# 	 	 loss(train :: test): 1.6634 :: 1.7249
# 	 	 accuracy (train :: test): 49.1% :: 47.5%
# 	 	 accuracy (last character) (train :: test): 46.9% :: 47.2%
#
# iteration 700  time: 10.9 seconds
# 	 	 loss(train :: test): 1.6434 :: 1.6270
# 	 	 accuracy (train :: test): 49.7% :: 50.3%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 48.4%
#
# iteration 800  time: 11.4 seconds
# 	 	 loss(train :: test): 1.6248 :: 1.6280
# 	 	 accuracy (train :: test): 50.0% :: 50.2%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 49.3%
#
# iteration 900  time: 11.8 seconds
# 	 	 loss(train :: test): 1.5601 :: 1.5993
# 	 	 accuracy (train :: test): 51.8% :: 50.8%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 52.1%
#
# iteration 1_000  time: 12.3 seconds
# 	 	 loss(train :: test): 1.5724 :: 1.6086
# 	 	 accuracy (train :: test): 52.1% :: 50.5%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 51.6%
#
# iteration 1_100  time: 12.8 seconds
# 	 	 loss(train :: test): 1.6188 :: 1.5739
# 	 	 accuracy (train :: test): 50.7% :: 51.6%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 52.8%
#
# iteration 1_200  time: 13.3 seconds
# 	 	 loss(train :: test): 1.5326 :: 1.5614
# 	 	 accuracy (train :: test): 53.3% :: 51.7%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 55.4%
#
# iteration 1_300  time: 13.7 seconds
# 	 	 loss(train :: test): 1.4996 :: 1.5453
# 	 	 accuracy (train :: test): 53.3% :: 52.3%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 54.6%
#
# iteration 1_400  time: 14.2 seconds
# 	 	 loss(train :: test): 1.5674 :: 1.5547
# 	 	 accuracy (train :: test): 51.8% :: 52.2%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 51.6%
#
# iteration 1_500  time: 14.7 seconds
# 	 	 loss(train :: test): 1.5108 :: 1.5443
# 	 	 accuracy (train :: test): 53.9% :: 52.2%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 53.7%
#
# iteration 1_600  time: 15.2 seconds
# 	 	 loss(train :: test): 1.5668 :: 1.5096
# 	 	 accuracy (train :: test): 51.9% :: 53.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 54.5%
#
# iteration 1_700  time: 15.6 seconds
# 	 	 loss(train :: test): 1.5041 :: 1.5188
# 	 	 accuracy (train :: test): 53.7% :: 53.2%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 56.7%
#
# iteration 1_800  time: 16.1 seconds
# 	 	 loss(train :: test): 1.5308 :: 1.5094
# 	 	 accuracy (train :: test): 53.0% :: 53.6%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 55.6%
#
# iteration 1_900  time: 16.6 seconds
# 	 	 loss(train :: test): 1.5075 :: 1.5045
# 	 	 accuracy (train :: test): 53.9% :: 53.1%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 52.6%
#
# iteration 2_000  time: 17.0 seconds
# 	 	 loss(train :: test): 1.5115 :: 1.5117
# 	 	 accuracy (train :: test): 53.1% :: 53.3%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 55.6%
#
# iteration 2_100  time: 17.5 seconds
# 	 	 loss(train :: test): 1.5021 :: 1.4842
# 	 	 accuracy (train :: test): 53.5% :: 53.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 56.3%
#
# iteration 2_200  time: 18.0 seconds
# 	 	 loss(train :: test): 1.4974 :: 1.4883
# 	 	 accuracy (train :: test): 54.4% :: 54.2%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 57.5%
#
# iteration 2_300  time: 18.5 seconds
# 	 	 loss(train :: test): 1.4734 :: 1.4926
# 	 	 accuracy (train :: test): 54.2% :: 53.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 53.5%
#
# iteration 2_400  time: 18.9 seconds
# 	 	 loss(train :: test): 1.4676 :: 1.5069
# 	 	 accuracy (train :: test): 54.2% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 56.1%
#
# iteration 2_500  time: 19.4 seconds
# 	 	 loss(train :: test): 1.4338 :: 1.4785
# 	 	 accuracy (train :: test): 55.7% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 55.8%
#
# iteration 2_600  time: 19.9 seconds
# 	 	 loss(train :: test): 1.4705 :: 1.4781
# 	 	 accuracy (train :: test): 54.8% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 55.7%
#
# iteration 2_700  time: 20.4 seconds
# 	 	 loss(train :: test): 1.4944 :: 1.4949
# 	 	 accuracy (train :: test): 53.6% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 56.4%
#
# iteration 2_800  time: 20.8 seconds
# 	 	 loss(train :: test): 1.4059 :: 1.4843
# 	 	 accuracy (train :: test): 55.4% :: 54.1%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 53.0%
#
# iteration 2_900  time: 21.3 seconds
# 	 	 loss(train :: test): 1.4834 :: 1.4687
# 	 	 accuracy (train :: test): 54.1% :: 54.4%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 55.7%
#
# iteration 3_000  time: 21.8 seconds
# 	 	 loss(train :: test): 1.4806 :: 1.4622
# 	 	 accuracy (train :: test): 53.4% :: 54.4%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 54.9%
#
# iteration 3_100  time: 22.3 seconds
# 	 	 loss(train :: test): 1.4255 :: 1.4431
# 	 	 accuracy (train :: test): 55.9% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 54.1%
#
# iteration 3_200  time: 22.7 seconds
# 	 	 loss(train :: test): 1.4143 :: 1.4606
# 	 	 accuracy (train :: test): 56.3% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 56.4%
#
# iteration 3_300  time: 23.2 seconds
# 	 	 loss(train :: test): 1.4749 :: 1.4361
# 	 	 accuracy (train :: test): 54.2% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 56.0%
#
# iteration 3_400  time: 23.7 seconds
# 	 	 loss(train :: test): 1.4763 :: 1.4600
# 	 	 accuracy (train :: test): 53.7% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 55.6%
#
# iteration 3_500  time: 24.2 seconds
# 	 	 loss(train :: test): 1.4345 :: 1.4694
# 	 	 accuracy (train :: test): 56.8% :: 54.4%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.9%
#
# iteration 3_600  time: 24.6 seconds
# 	 	 loss(train :: test): 1.4462 :: 1.4815
# 	 	 accuracy (train :: test): 54.7% :: 54.4%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 53.7%
#
# iteration 3_700  time: 25.1 seconds
# 	 	 loss(train :: test): 1.4093 :: 1.4627
# 	 	 accuracy (train :: test): 54.7% :: 54.7%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 58.9%
#
# iteration 3_800  time: 25.6 seconds
# 	 	 loss(train :: test): 1.4384 :: 1.4539
# 	 	 accuracy (train :: test): 55.4% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 57.4%
#
# iteration 3_900  time: 26.1 seconds
# 	 	 loss(train :: test): 1.4280 :: 1.4510
# 	 	 accuracy (train :: test): 55.6% :: 54.7%
# 	 	 accuracy (last character) (train :: test): 67.2% :: 52.9%
#
# iteration 4_000  time: 26.5 seconds
# 	 	 loss(train :: test): 1.4481 :: 1.4413
# 	 	 accuracy (train :: test): 54.7% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 56.4%
#
# iteration 4_100  time: 27.0 seconds
# 	 	 loss(train :: test): 1.3556 :: 1.4464
# 	 	 accuracy (train :: test): 57.1% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 58.0%
#
# iteration 4_200  time: 27.5 seconds
# 	 	 loss(train :: test): 1.4364 :: 1.4512
# 	 	 accuracy (train :: test): 56.0% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 56.8%
#
# iteration 4_300  time: 28.0 seconds
# 	 	 loss(train :: test): 1.3824 :: 1.4515
# 	 	 accuracy (train :: test): 56.7% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 56.4%
#
# iteration 4_400  time: 28.4 seconds
# 	 	 loss(train :: test): 1.4647 :: 1.4650
# 	 	 accuracy (train :: test): 53.5% :: 54.0%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 54.0%
#
# iteration 4_500  time: 28.9 seconds
# 	 	 loss(train :: test): 1.3884 :: 1.4369
# 	 	 accuracy (train :: test): 56.6% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 59.0%
#
# iteration 4_600  time: 29.4 seconds
# 	 	 loss(train :: test): 1.3384 :: 1.4482
# 	 	 accuracy (train :: test): 57.6% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.5%
#
# iteration 4_700  time: 29.9 seconds
# 	 	 loss(train :: test): 1.3970 :: 1.4689
# 	 	 accuracy (train :: test): 55.6% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.5%
#
# iteration 4_800  time: 30.3 seconds
# 	 	 loss(train :: test): 1.3902 :: 1.4335
# 	 	 accuracy (train :: test): 56.5% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.6%
#
# iteration 4_900  time: 30.8 seconds
# 	 	 loss(train :: test): 1.4855 :: 1.4452
# 	 	 accuracy (train :: test): 54.6% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 54.9%
#
# iteration 4_999  time: 31.3 seconds
# 	 	 loss(train :: test): 1.4817 :: 1.4456
# 	 	 accuracy (train :: test): 53.9% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 57.2%
#
#
# ============================================================
# Training with temperature = 1.0
# ============================================================
#
# iteration 0  time: 5.9 seconds
# 	 	 loss(train :: test): 3.9267 :: 3.4638
# 	 	 accuracy (train :: test): 2.4% :: 17.1%
# 	 	 accuracy (last character) (train :: test): 3.1% :: 15.5%
#
# iteration 100  time: 8.1 seconds
# 	 	 loss(train :: test): 2.2895 :: 2.2866
# 	 	 accuracy (train :: test): 31.2% :: 30.6%
# 	 	 accuracy (last character) (train :: test): 18.8% :: 27.8%
#
# iteration 200  time: 8.4 seconds
# 	 	 loss(train :: test): 1.9894 :: 1.9743
# 	 	 accuracy (train :: test): 39.5% :: 39.5%
# 	 	 accuracy (last character) (train :: test): 37.5% :: 37.9%
#
# iteration 300  time: 8.8 seconds
# 	 	 loss(train :: test): 1.7940 :: 1.8539
# 	 	 accuracy (train :: test): 45.4% :: 43.4%
# 	 	 accuracy (last character) (train :: test): 40.6% :: 42.1%
#
# iteration 400  time: 9.1 seconds
# 	 	 loss(train :: test): 1.7186 :: 1.7676
# 	 	 accuracy (train :: test): 47.9% :: 46.0%
# 	 	 accuracy (last character) (train :: test): 47.7% :: 50.0%
#
# iteration 500  time: 9.4 seconds
# 	 	 loss(train :: test): 1.6712 :: 1.7162
# 	 	 accuracy (train :: test): 48.6% :: 47.6%
# 	 	 accuracy (last character) (train :: test): 46.1% :: 49.2%
#
# iteration 600  time: 9.7 seconds
# 	 	 loss(train :: test): 1.6360 :: 1.6708
# 	 	 accuracy (train :: test): 49.0% :: 48.7%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 49.1%
#
# iteration 700  time: 10.0 seconds
# 	 	 loss(train :: test): 1.6195 :: 1.6161
# 	 	 accuracy (train :: test): 50.2% :: 50.2%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 52.5%
#
# iteration 800  time: 10.3 seconds
# 	 	 loss(train :: test): 1.5941 :: 1.6029
# 	 	 accuracy (train :: test): 50.5% :: 50.6%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 51.8%
#
# iteration 900  time: 10.7 seconds
# 	 	 loss(train :: test): 1.5676 :: 1.6012
# 	 	 accuracy (train :: test): 51.0% :: 50.6%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 47.9%
#
# iteration 1_000  time: 11.0 seconds
# 	 	 loss(train :: test): 1.5577 :: 1.5730
# 	 	 accuracy (train :: test): 51.2% :: 51.9%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 54.5%
#
# iteration 1_100  time: 11.3 seconds
# 	 	 loss(train :: test): 1.5842 :: 1.5646
# 	 	 accuracy (train :: test): 51.7% :: 52.1%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 53.4%
#
# iteration 1_200  time: 11.6 seconds
# 	 	 loss(train :: test): 1.5400 :: 1.5377
# 	 	 accuracy (train :: test): 52.2% :: 52.5%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 57.3%
#
# iteration 1_300  time: 11.9 seconds
# 	 	 loss(train :: test): 1.4866 :: 1.5314
# 	 	 accuracy (train :: test): 54.2% :: 52.8%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 55.6%
#
# iteration 1_400  time: 12.2 seconds
# 	 	 loss(train :: test): 1.5035 :: 1.5012
# 	 	 accuracy (train :: test): 54.1% :: 53.3%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 54.2%
#
# iteration 1_500  time: 12.5 seconds
# 	 	 loss(train :: test): 1.5287 :: 1.5150
# 	 	 accuracy (train :: test): 52.3% :: 53.1%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 55.6%
#
# iteration 1_600  time: 12.8 seconds
# 	 	 loss(train :: test): 1.5171 :: 1.4927
# 	 	 accuracy (train :: test): 52.5% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 55.7%
#
# iteration 1_700  time: 13.2 seconds
# 	 	 loss(train :: test): 1.5097 :: 1.5088
# 	 	 accuracy (train :: test): 53.4% :: 53.0%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 53.4%
#
# iteration 1_800  time: 13.5 seconds
# 	 	 loss(train :: test): 1.5305 :: 1.5102
# 	 	 accuracy (train :: test): 52.9% :: 53.6%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 55.7%
#
# iteration 1_900  time: 13.8 seconds
# 	 	 loss(train :: test): 1.5196 :: 1.4995
# 	 	 accuracy (train :: test): 52.6% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 53.3%
#
# iteration 2_000  time: 14.1 seconds
# 	 	 loss(train :: test): 1.4981 :: 1.4972
# 	 	 accuracy (train :: test): 53.5% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 47.7% :: 56.4%
#
# iteration 2_100  time: 14.4 seconds
# 	 	 loss(train :: test): 1.4124 :: 1.5078
# 	 	 accuracy (train :: test): 56.2% :: 53.2%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 52.9%
#
# iteration 2_200  time: 14.7 seconds
# 	 	 loss(train :: test): 1.5014 :: 1.4759
# 	 	 accuracy (train :: test): 53.7% :: 54.2%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.8%
#
# iteration 2_300  time: 15.0 seconds
# 	 	 loss(train :: test): 1.4927 :: 1.4567
# 	 	 accuracy (train :: test): 54.0% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.5%
#
# iteration 2_400  time: 15.4 seconds
# 	 	 loss(train :: test): 1.4424 :: 1.4781
# 	 	 accuracy (train :: test): 55.2% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 56.3%
#
# iteration 2_500  time: 15.7 seconds
# 	 	 loss(train :: test): 1.4656 :: 1.4877
# 	 	 accuracy (train :: test): 54.6% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 48.4% :: 54.6%
#
# iteration 2_600  time: 16.0 seconds
# 	 	 loss(train :: test): 1.4434 :: 1.4795
# 	 	 accuracy (train :: test): 55.3% :: 54.0%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 54.7%
#
# iteration 2_700  time: 16.3 seconds
# 	 	 loss(train :: test): 1.4556 :: 1.4830
# 	 	 accuracy (train :: test): 54.2% :: 54.2%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 51.8%
#
# iteration 2_800  time: 16.5 seconds
# 	 	 loss(train :: test): 1.4943 :: 1.4799
# 	 	 accuracy (train :: test): 54.2% :: 54.0%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 56.8%
#
# iteration 2_900  time: 16.8 seconds
# 	 	 loss(train :: test): 1.4251 :: 1.4730
# 	 	 accuracy (train :: test): 56.0% :: 54.4%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 57.0%
#
# iteration 3_000  time: 17.1 seconds
# 	 	 loss(train :: test): 1.5008 :: 1.4625
# 	 	 accuracy (train :: test): 53.2% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 57.0%
#
# iteration 3_100  time: 17.4 seconds
# 	 	 loss(train :: test): 1.4133 :: 1.4869
# 	 	 accuracy (train :: test): 54.8% :: 53.7%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 56.1%
#
# iteration 3_200  time: 17.7 seconds
# 	 	 loss(train :: test): 1.4604 :: 1.4675
# 	 	 accuracy (train :: test): 53.8% :: 54.6%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 56.9%
#
# iteration 3_300  time: 18.0 seconds
# 	 	 loss(train :: test): 1.4881 :: 1.4393
# 	 	 accuracy (train :: test): 53.6% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.0%
#
# iteration 3_400  time: 18.3 seconds
# 	 	 loss(train :: test): 1.4427 :: 1.4644
# 	 	 accuracy (train :: test): 54.8% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 54.7%
#
# iteration 3_500  time: 18.6 seconds
# 	 	 loss(train :: test): 1.4609 :: 1.4331
# 	 	 accuracy (train :: test): 53.7% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 56.9%
#
# iteration 3_600  time: 18.9 seconds
# 	 	 loss(train :: test): 1.4892 :: 1.4584
# 	 	 accuracy (train :: test): 53.9% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 71.9% :: 53.9%
#
# iteration 3_700  time: 19.2 seconds
# 	 	 loss(train :: test): 1.4097 :: 1.4541
# 	 	 accuracy (train :: test): 56.0% :: 54.6%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.5%
#
# iteration 3_800  time: 19.4 seconds
# 	 	 loss(train :: test): 1.4210 :: 1.4299
# 	 	 accuracy (train :: test): 56.5% :: 55.3%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 58.7%
#
# iteration 3_900  time: 19.7 seconds
# 	 	 loss(train :: test): 1.4474 :: 1.4372
# 	 	 accuracy (train :: test): 55.3% :: 55.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 58.8%
#
# iteration 4_000  time: 20.0 seconds
# 	 	 loss(train :: test): 1.4451 :: 1.4487
# 	 	 accuracy (train :: test): 55.0% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 57.0%
#
# iteration 4_100  time: 20.3 seconds
# 	 	 loss(train :: test): 1.4178 :: 1.4349
# 	 	 accuracy (train :: test): 55.4% :: 55.3%
# 	 	 accuracy (last character) (train :: test): 64.1% :: 60.9%
#
# iteration 4_200  time: 20.6 seconds
# 	 	 loss(train :: test): 1.4213 :: 1.4451
# 	 	 accuracy (train :: test): 56.0% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 64.8% :: 57.4%
#
# iteration 4_300  time: 20.9 seconds
# 	 	 loss(train :: test): 1.4517 :: 1.4417
# 	 	 accuracy (train :: test): 55.2% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 54.1%
#
# iteration 4_400  time: 21.2 seconds
# 	 	 loss(train :: test): 1.4543 :: 1.4501
# 	 	 accuracy (train :: test): 54.9% :: 55.3%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 56.3%
#
# iteration 4_500  time: 21.5 seconds
# 	 	 loss(train :: test): 1.4341 :: 1.4495
# 	 	 accuracy (train :: test): 54.5% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 59.1%
#
# iteration 4_600  time: 21.9 seconds
# 	 	 loss(train :: test): 1.4641 :: 1.4297
# 	 	 accuracy (train :: test): 54.5% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.0%
#
# iteration 4_700  time: 22.2 seconds
# 	 	 loss(train :: test): 1.4084 :: 1.4445
# 	 	 accuracy (train :: test): 56.1% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 54.9%
#
# iteration 4_800  time: 22.5 seconds
# 	 	 loss(train :: test): 1.4288 :: 1.4308
# 	 	 accuracy (train :: test): 55.5% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 61.7% :: 56.2%
#
# iteration 4_900  time: 22.8 seconds
# 	 	 loss(train :: test): 1.4996 :: 1.4198
# 	 	 accuracy (train :: test): 53.8% :: 55.7%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 56.5%
#
# iteration 4_999  time: 23.1 seconds
# 	 	 loss(train :: test): 1.4265 :: 1.4307
# 	 	 accuracy (train :: test): 55.2% :: 55.2%
# 	 	 accuracy (last character) (train :: test): 62.5% :: 58.3%
#
#
# ============================================================
# Training with temperature = 1.2
# ============================================================
#
# iteration 0  time: 6.5 seconds
# 	 	 loss(train :: test): 3.7586 :: 3.3617
# 	 	 accuracy (train :: test): 2.4% :: 17.0%
# 	 	 accuracy (last character) (train :: test): 3.9% :: 16.6%
#
# iteration 100  time: 8.7 seconds
# 	 	 loss(train :: test): 2.2676 :: 2.2618
# 	 	 accuracy (train :: test): 31.7% :: 31.3%
# 	 	 accuracy (last character) (train :: test): 30.5% :: 29.1%
#
# iteration 200  time: 9.1 seconds
# 	 	 loss(train :: test): 1.9535 :: 1.9695
# 	 	 accuracy (train :: test): 40.8% :: 39.8%
# 	 	 accuracy (last character) (train :: test): 35.2% :: 40.0%
#
# iteration 300  time: 9.4 seconds
# 	 	 loss(train :: test): 1.8051 :: 1.8264
# 	 	 accuracy (train :: test): 44.2% :: 44.4%
# 	 	 accuracy (last character) (train :: test): 43.8% :: 43.8%
#
# iteration 400  time: 9.7 seconds
# 	 	 loss(train :: test): 1.7489 :: 1.7466
# 	 	 accuracy (train :: test): 46.5% :: 46.9%
# 	 	 accuracy (last character) (train :: test): 50.8% :: 47.7%
#
# iteration 500  time: 10.0 seconds
# 	 	 loss(train :: test): 1.6245 :: 1.7055
# 	 	 accuracy (train :: test): 50.3% :: 47.9%
# 	 	 accuracy (last character) (train :: test): 49.2% :: 48.6%
#
# iteration 600  time: 10.4 seconds
# 	 	 loss(train :: test): 1.6504 :: 1.6483
# 	 	 accuracy (train :: test): 48.9% :: 49.9%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 49.6%
#
# iteration 700  time: 10.7 seconds
# 	 	 loss(train :: test): 1.5984 :: 1.6350
# 	 	 accuracy (train :: test): 50.4% :: 50.1%
# 	 	 accuracy (last character) (train :: test): 53.1% :: 52.3%
#
# iteration 800  time: 11.0 seconds
# 	 	 loss(train :: test): 1.6109 :: 1.5931
# 	 	 accuracy (train :: test): 51.0% :: 51.2%
# 	 	 accuracy (last character) (train :: test): 44.5% :: 53.4%
#
# iteration 900  time: 11.3 seconds
# 	 	 loss(train :: test): 1.5773 :: 1.5851
# 	 	 accuracy (train :: test): 52.2% :: 51.3%
# 	 	 accuracy (last character) (train :: test): 52.3% :: 54.4%
#
# iteration 1_000  time: 11.6 seconds
# 	 	 loss(train :: test): 1.5937 :: 1.5654
# 	 	 accuracy (train :: test): 50.9% :: 52.1%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 52.3%
#
# iteration 1_100  time: 12.0 seconds
# 	 	 loss(train :: test): 1.5740 :: 1.5574
# 	 	 accuracy (train :: test): 51.5% :: 52.3%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 54.0%
#
# iteration 1_200  time: 12.3 seconds
# 	 	 loss(train :: test): 1.5153 :: 1.5265
# 	 	 accuracy (train :: test): 53.5% :: 52.9%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 56.4%
#
# iteration 1_300  time: 12.6 seconds
# 	 	 loss(train :: test): 1.5021 :: 1.5358
# 	 	 accuracy (train :: test): 53.2% :: 52.5%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 56.8%
#
# iteration 1_400  time: 12.9 seconds
# 	 	 loss(train :: test): 1.5336 :: 1.5173
# 	 	 accuracy (train :: test): 52.3% :: 53.1%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 54.8%
#
# iteration 1_500  time: 13.2 seconds
# 	 	 loss(train :: test): 1.5323 :: 1.5259
# 	 	 accuracy (train :: test): 52.7% :: 52.8%
# 	 	 accuracy (last character) (train :: test): 46.1% :: 55.5%
#
# iteration 1_600  time: 13.6 seconds
# 	 	 loss(train :: test): 1.4670 :: 1.5015
# 	 	 accuracy (train :: test): 54.9% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 57.1%
#
# iteration 1_700  time: 13.9 seconds
# 	 	 loss(train :: test): 1.5178 :: 1.4990
# 	 	 accuracy (train :: test): 52.9% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 53.5%
#
# iteration 1_800  time: 14.2 seconds
# 	 	 loss(train :: test): 1.5171 :: 1.4980
# 	 	 accuracy (train :: test): 53.2% :: 53.6%
# 	 	 accuracy (last character) (train :: test): 68.0% :: 55.7%
#
# iteration 1_900  time: 14.5 seconds
# 	 	 loss(train :: test): 1.4881 :: 1.4931
# 	 	 accuracy (train :: test): 54.1% :: 53.5%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 53.6%
#
# iteration 2_000  time: 14.8 seconds
# 	 	 loss(train :: test): 1.5456 :: 1.4921
# 	 	 accuracy (train :: test): 52.9% :: 53.8%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 55.0%
#
# iteration 2_100  time: 15.1 seconds
# 	 	 loss(train :: test): 1.4808 :: 1.4710
# 	 	 accuracy (train :: test): 54.6% :: 54.0%
# 	 	 accuracy (last character) (train :: test): 50.0% :: 58.4%
#
# iteration 2_200  time: 15.5 seconds
# 	 	 loss(train :: test): 1.4214 :: 1.4804
# 	 	 accuracy (train :: test): 55.8% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 53.9% :: 55.2%
#
# iteration 2_300  time: 15.8 seconds
# 	 	 loss(train :: test): 1.4587 :: 1.4654
# 	 	 accuracy (train :: test): 55.4% :: 54.6%
# 	 	 accuracy (last character) (train :: test): 63.3% :: 55.6%
#
# iteration 2_400  time: 16.1 seconds
# 	 	 loss(train :: test): 1.4917 :: 1.4726
# 	 	 accuracy (train :: test): 53.6% :: 54.1%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 57.7%
#
# iteration 2_500  time: 16.4 seconds
# 	 	 loss(train :: test): 1.5107 :: 1.4740
# 	 	 accuracy (train :: test): 52.9% :: 54.3%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 57.3%
#
# iteration 2_600  time: 16.7 seconds
# 	 	 loss(train :: test): 1.4483 :: 1.4690
# 	 	 accuracy (train :: test): 55.2% :: 54.2%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 54.7%
#
# iteration 2_700  time: 17.1 seconds
# 	 	 loss(train :: test): 1.4157 :: 1.4624
# 	 	 accuracy (train :: test): 55.8% :: 54.7%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 56.5%
#
# iteration 2_800  time: 17.4 seconds
# 	 	 loss(train :: test): 1.5047 :: 1.4558
# 	 	 accuracy (train :: test): 53.1% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 57.1%
#
# iteration 2_900  time: 17.7 seconds
# 	 	 loss(train :: test): 1.4954 :: 1.4586
# 	 	 accuracy (train :: test): 54.2% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 56.9%
#
# iteration 3_000  time: 18.0 seconds
# 	 	 loss(train :: test): 1.4422 :: 1.4685
# 	 	 accuracy (train :: test): 55.5% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 57.7%
#
# iteration 3_100  time: 18.3 seconds
# 	 	 loss(train :: test): 1.4671 :: 1.4498
# 	 	 accuracy (train :: test): 54.3% :: 55.0%
# 	 	 accuracy (last character) (train :: test): 54.7% :: 57.9%
#
# iteration 3_200  time: 18.6 seconds
# 	 	 loss(train :: test): 1.4795 :: 1.4592
# 	 	 accuracy (train :: test): 54.8% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 57.7%
#
# iteration 3_300  time: 19.0 seconds
# 	 	 loss(train :: test): 1.4319 :: 1.4666
# 	 	 accuracy (train :: test): 54.9% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 59.5%
#
# iteration 3_400  time: 19.3 seconds
# 	 	 loss(train :: test): 1.4486 :: 1.4547
# 	 	 accuracy (train :: test): 54.0% :: 54.8%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 56.8%
#
# iteration 3_500  time: 19.6 seconds
# 	 	 loss(train :: test): 1.4179 :: 1.4343
# 	 	 accuracy (train :: test): 55.9% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 58.5%
#
# iteration 3_600  time: 19.9 seconds
# 	 	 loss(train :: test): 1.4165 :: 1.4332
# 	 	 accuracy (train :: test): 55.3% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 57.3%
#
# iteration 3_700  time: 20.2 seconds
# 	 	 loss(train :: test): 1.4450 :: 1.4560
# 	 	 accuracy (train :: test): 55.0% :: 54.5%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.2%
#
# iteration 3_800  time: 20.5 seconds
# 	 	 loss(train :: test): 1.4293 :: 1.4450
# 	 	 accuracy (train :: test): 56.1% :: 54.7%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.5%
#
# iteration 3_900  time: 20.8 seconds
# 	 	 loss(train :: test): 1.4517 :: 1.4572
# 	 	 accuracy (train :: test): 55.2% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 57.3%
#
# iteration 4_000  time: 21.2 seconds
# 	 	 loss(train :: test): 1.4203 :: 1.4313
# 	 	 accuracy (train :: test): 55.2% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 59.4% :: 60.1%
#
# iteration 4_100  time: 21.5 seconds
# 	 	 loss(train :: test): 1.4238 :: 1.4271
# 	 	 accuracy (train :: test): 55.4% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 59.8%
#
# iteration 4_200  time: 21.8 seconds
# 	 	 loss(train :: test): 1.4578 :: 1.4481
# 	 	 accuracy (train :: test): 54.7% :: 54.9%
# 	 	 accuracy (last character) (train :: test): 57.0% :: 55.2%
#
# iteration 4_300  time: 22.1 seconds
# 	 	 loss(train :: test): 1.3768 :: 1.4301
# 	 	 accuracy (train :: test): 56.9% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 60.9% :: 56.0%
#
# iteration 4_400  time: 22.4 seconds
# 	 	 loss(train :: test): 1.3984 :: 1.4252
# 	 	 accuracy (train :: test): 57.4% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 55.5% :: 58.5%
#
# iteration 4_500  time: 22.8 seconds
# 	 	 loss(train :: test): 1.4662 :: 1.4292
# 	 	 accuracy (train :: test): 54.2% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 59.5%
#
# iteration 4_600  time: 23.1 seconds
# 	 	 loss(train :: test): 1.4039 :: 1.4279
# 	 	 accuracy (train :: test): 55.8% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 56.2% :: 56.7%
#
# iteration 4_700  time: 23.4 seconds
# 	 	 loss(train :: test): 1.4144 :: 1.4281
# 	 	 accuracy (train :: test): 55.3% :: 55.5%
# 	 	 accuracy (last character) (train :: test): 57.8% :: 57.7%
#
# iteration 4_800  time: 23.7 seconds
# 	 	 loss(train :: test): 1.4635 :: 1.4333
# 	 	 accuracy (train :: test): 54.7% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 60.2% :: 57.5%
#
# iteration 4_900  time: 24.0 seconds
# 	 	 loss(train :: test): 1.3930 :: 1.4339
# 	 	 accuracy (train :: test): 57.4% :: 55.4%
# 	 	 accuracy (last character) (train :: test): 58.6% :: 59.2%
#
# iteration 4_999  time: 24.3 seconds
# 	 	 loss(train :: test): 1.4036 :: 1.4116
# 	 	 accuracy (train :: test): 56.7% :: 55.9%
# 	 	 accuracy (last character) (train :: test): 51.6% :: 59.1%

# %%
def plot_temperature_comparison(results):
    """
    Plot comparison of different temperature values.
    
    Args:
        results: Dictionary with training histories for each temperature
    """
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('Temperature Scaling Comparison', fontsize=16, fontweight='bold')
    
    colors = ['#d62728', '#ff7f0e', '#1f77b4', '#2ca02c']
    labels_map = {
        0.5: 'Very Sharp (0.5)',
        0.8: 'Sharp (0.8)',
        1.0: 'Baseline (1.0)',
        1.2: 'Soft (1.2)'
    }
    
    # Plot 1: Training Loss over time
    ax1 = axes[0, 0]
    for idx, (temp_val, data) in enumerate(results.items()):
        ax1.plot(data['time_train'], data['loss_train'], 
                label=labels_map.get(temp_val, f'{temp_val}'), linewidth=1.5, 
                color=colors[idx % len(colors)], alpha=0.7)
    ax1.set_xlabel('Time (seconds)', fontsize=12)
    ax1.set_ylabel('Training Loss', fontsize=12)
    ax1.set_title('Training Loss vs Time', fontsize=13, fontweight='bold')
    ax1.legend(fontsize=10)
    ax1.grid(True, alpha=0.3)
    
    # Plot 2: Test Loss
    ax2 = axes[0, 1]
    for idx, (temp_val, data) in enumerate(results.items()):
        ax2.plot(data['time_test'], data['loss_test'], 
                label=labels_map.get(temp_val, f'{temp_val}'), linewidth=2, 
                marker='o', markersize=4, color=colors[idx % len(colors)])
    ax2.set_xlabel('Time (seconds)', fontsize=12)
    ax2.set_ylabel('Test Loss', fontsize=12)
    ax2.set_title('Test Loss vs Time', fontsize=13, fontweight='bold')
    ax2.legend(fontsize=10)
    ax2.grid(True, alpha=0.3)
    
    # Plot 3: Test Accuracy
    ax3 = axes[1, 0]
    for idx, (temp_val, data) in enumerate(results.items()):
        acc_percent = [a * 100 for a in data['acc_test']]
        ax3.plot(data['time_test'], acc_percent, 
                label=labels_map.get(temp_val, f'{temp_val}'), linewidth=2, 
                marker='s', markersize=4, color=colors[idx % len(colors)])
    ax3.set_xlabel('Time (seconds)', fontsize=12)
    ax3.set_ylabel('Test Accuracy (%)', fontsize=12)
    ax3.set_title('Overall Test Accuracy', fontsize=13, fontweight='bold')
    ax3.legend(fontsize=10)
    ax3.grid(True, alpha=0.3)
    
    # Plot 4: Last Token Accuracy
    ax4 = axes[1, 1]
    for idx, (temp_val, data) in enumerate(results.items()):
        acc_last_percent = [a * 100 for a in data['acc_last_test']]
        ax4.plot(data['time_test'], acc_last_percent, 
                label=labels_map.get(temp_val, f'{temp_val}'), linewidth=2, 
                marker='^', markersize=4, color=colors[idx % len(colors)])
    ax4.set_xlabel('Time (seconds)', fontsize=12)
    ax4.set_ylabel('Last Token Accuracy (%)', fontsize=12)
    ax4.set_title('Last Token Test Accuracy', fontsize=13, fontweight='bold')
    ax4.legend(fontsize=10)
    ax4.grid(True, alpha=0.3)
    
    plt.tight_layout()
    return fig


def plot_temperature_final_comparison(results):
    """
    Create bar charts comparing final metrics for temperature scaling.
    """
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))
    fig.suptitle('Final Metrics Comparison - Temperature Scaling', fontsize=16, fontweight='bold')
    
    temp_vals = list(results.keys())
    labels = [f'{v}' for v in temp_vals]
    
    # Extract final values
    final_loss = [results[v]['loss_test'][-1] for v in temp_vals]
    final_acc = [results[v]['acc_test'][-1] * 100 for v in temp_vals]
    final_acc_last = [results[v]['acc_last_test'][-1] * 100 for v in temp_vals]
    
    colors = ['#d62728', '#ff7f0e', '#1f77b4', '#2ca02c']
    
    # Plot 1: Final Test Loss
    ax1 = axes[0]
    bars1 = ax1.bar(labels, final_loss, color=colors[:len(labels)], alpha=0.7)
    ax1.set_xlabel('Temperature', fontsize=12)
    ax1.set_ylabel('Test Loss', fontsize=12)
    ax1.set_title('Final Test Loss', fontsize=13, fontweight='bold')
    ax1.grid(True, alpha=0.3, axis='y')
    for bar in bars1:
        height = bar.get_height()
        ax1.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.4f}', ha='center', va='bottom', fontsize=9)
    
    # Plot 2: Final Test Accuracy
    ax2 = axes[1]
    bars2 = ax2.bar(labels, final_acc, color=colors[:len(labels)], alpha=0.7)
    ax2.set_xlabel('Temperature', fontsize=12)
    ax2.set_ylabel('Accuracy (%)', fontsize=12)
    ax2.set_title('Final Test Accuracy', fontsize=13, fontweight='bold')
    ax2.grid(True, alpha=0.3, axis='y')
    ax2.set_ylim([0, 100])
    for bar in bars2:
        height = bar.get_height()
        ax2.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}%', ha='center', va='bottom', fontsize=9)
    
    # Plot 3: Final Last Token Accuracy
    ax3 = axes[2]
    bars3 = ax3.bar(labels, final_acc_last, color=colors[:len(labels)], alpha=0.7)
    ax3.set_xlabel('Temperature', fontsize=12)
    ax3.set_ylabel('Accuracy (%)', fontsize=12)
    ax3.set_title('Final Last Token Accuracy', fontsize=13, fontweight='bold')
    ax3.grid(True, alpha=0.3, axis='y')
    ax3.set_ylim([0, 100])
    for bar in bars3:
        height = bar.get_height()
        ax3.text(bar.get_x() + bar.get_width()/2., height,
                f'{height:.1f}%', ha='center', va='bottom', fontsize=9)
    
    plt.tight_layout()
    return fig


def print_temperature_summary(results):
    """Print summary table of temperature results."""
    print("\n" + "="*80)
    print("FINAL RESULTS SUMMARY - TEMPERATURE SCALING")
    print("="*80)
    print(f"{'Temperature':<20} {'Test Loss':<15} {'Test Acc (%)':<15} {'Last Token Acc (%)':<20}")
    print("-"*80)
    for temp_val in results.keys():
        data = results[temp_val]
        print(f"{temp_val:<20.1f} {data['loss_test'][-1]:<15.4f} "
              f"{data['acc_test'][-1]*100:<15.2f} {data['acc_last_test'][-1]*100:<20.2f}")

# %%
# Create visualizations
fig1 = plot_temperature_comparison(results)
plt.show()

fig2 = plot_temperature_final_comparison(results)
plt.show()

# Print summary
print_temperature_summary(results)
# Out:
# ================================================================================
# FINAL RESULTS SUMMARY - TEMPERATURE SCALING
# ================================================================================
# Temperature          Test Loss       Test Acc (%)    Last Token Acc (%)
# --------------------------------------------------------------------------------
# 0.5                  1.4490          54.97           56.93
# 0.8                  1.4456          54.81           57.23
# 1.0                  1.4307          55.21           58.30
# 1.2                  1.4116          55.93           59.08

# %%
#test
