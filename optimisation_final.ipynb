# %%
# !git clone https://github.com/beckhamtoh/char-llm-assignment.git
# %cd char-llm-assignment
# Out:
# Cloning into 'char-llm-assignment'...
# remote: Enumerating objects: 226, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 226 (delta 11), reused 20 (delta 6), pack-reused 197 (from 1)
# Receiving objects: 100% (226/226), 35.20 MiB | 24.30 MiB/s, done.
# Resolving deltas: 100% (106/106), done.
# /kaggle/working/char-llm-assignment

# %%
# Enable autoreload of local Python modules (e.g., models)
# %load_ext autoreload
# %autoreload 2

# manual reload for local modules
import importlib

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import numpy as np
import jax
import jax.numpy as jnp
import optax
import time
import matplotlib.pyplot as plt

# local imports
import models.models as models
import util.generation as generation

# %%
# initialize the jax random key
key = jax.random.key(0)

# %% [markdown]
# # Load data

# %%
# load the ./data/text8_train.txt and ./data/text8_test.txt files
with open("./data/text8_train.txt", "r") as f:
    train_text = f.read()
with open("./data/text8_test.txt", "r") as f:
    test_text = f.read()

# print the length of the training text and test text
print(f"Length of training text: {len(train_text):_} characters")
print(f"Length of test text: {len(test_text):_} characters")
# Out:
# Length of training text: 90_000_000 characters
# Length of test text: 5_000_000 characters

# %%
# Build vocabulary (lowercase + space + a few punctuations)
char_set = list("abcdefghijklmnopqrstuvwxyz ")
char_to_int = {ch:i for i,ch in enumerate(char_set)}
int_to_char = {i:ch for ch,i in char_to_int.items()}

def encode(s):
    """Encode string to array of integers"""
    ids = [char_to_int[c] for c in s]
    return np.array(ids, dtype=np.uint8)  # use np.uint8 to save space

# %%
# encode the text
train_text_int = encode(train_text)
test_text_int = encode(test_text)

# %%
# sanity check: display a few random characters from the training text
T = 128
for _ in range(5):
    # choose random position in text
    N = np.random.randint(low=0, high=len(train_text)-T)
    print(train_text[N:N+T])
    print()
# Out:
# abuses generally took the form of the establishment of new monastic orders with new and more stringent rules requiring a modific
#
# ons and possible discoveries not yet recognized but as ways of advancing present knowledge much of his writing on physics is inc
#
# added in the form of a pleated cloth in the same tartan as the kilt cast over the shoulder and fastened below the shoulder with
#
#  four c three is made by heating a mixture of the elements above one zero zero zero c the pale yellow crystals have a complex la
#
# ads german gepard and similar versions with the british marksman turret which was also adapted for a number of other users itali

# %% [markdown]
# # Create a basic Transformer model

# %%
def create_train_state(rng, vocab_size=27, d_model=64, n_layers=6, n_heads=8, max_len=128):
    # create a basic Transformer model
    model = models.DecoderOnlyTransformer(vocab_size, d_model, n_layers, n_heads, max_len)
    # create a dummy input for initialization
    dummy = jnp.zeros((1, min(16, max_len)), dtype=jnp.int32)
    # pass the dummy input to the model to initialize the parameters
    params = model.init({"params": rng}, dummy)["params"]
    return model, params

# %%
# vocab size
vocab_size= len(char_set)

# internal model dimensions
d_model=512

# number of attention heads
n_heads=8

# number of Transformer layers
n_layers=4

# maximum sequence length
max_len=128

model, params = create_train_state(key, vocab_size, d_model, n_layers, n_heads, max_len)

# %%
# compute the number of parameters
def count_params(params):
    return sum(x.size for x in jax.tree_util.tree_leaves(params))
print(f"Number of parameters: {count_params(params):_}")
# Out:
# Number of parameters: 12_695_552

# %%
# sanity check: create a batch of data & run a forward pass
B, T = 4, 32
batch = jax.random.randint(
    key=key,
    shape=(B, T), minval=0, maxval=len(char_set))
logits = model.apply({"params": params}, batch)

print("batch shape:", batch.shape)  # (B, T)
print("logits shape:", logits.shape)  # (B, T, vocab_size)
# Out:
# batch shape: (4, 32)
# logits shape: (4, 32, 27)

# %% [markdown]
# # Loss function

# %%
@jax.jit
def loss_and_metrics(logits, targets):
    """Compute cross-entropy loss and accuracy.

    Assumes `targets` contains only valid integer class ids in [0, V-1] (no -1 ignore tokens).

    Args:
      logits: (B, T, V) float array of unnormalized scores.
      targets: (B, T) integer array with ground-truth class ids.

    Returns:
      loss: scalar average cross-entropy over all positions.
      metrics: dict with keys "loss" and "acc" (both scalars).
    """
    # Flatten batch/time dims so optax works on shape (N, V) and (N,)
    vocab = logits.shape[-1]
    flat_logits = logits.reshape(-1, vocab)
    flat_targets = targets.reshape(-1)

    # Per-position cross-entropy, then mean over all positions
    per_pos = optax.softmax_cross_entropy_with_integer_labels(flat_logits, flat_targets)
    loss = per_pos.mean()

    # prediction over all positions
    preds = jnp.argmax(logits, axis=-1)  # (B, T)

    # compute accuracy over only the last position
    is_match = preds == targets

    # Accuracy over all positions
    acc_all = jnp.mean(is_match.astype(jnp.float32))

    # Accuracy over only last position
    acc_last = jnp.mean(is_match.astype(jnp.float32)[:,-1])

    return loss, {"loss": loss, "acc": acc_all, "acc_last": acc_last}

# %% [markdown]
# # Optimization step:

# %%
# create an update function
def train_step(params, opt_state, x, y, tx):
    """Single optimization step using optax optimizer.

    Args:
      params: pytree of model parameters.
      opt_state: optax optimizer state corresponding to `params`.
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
      tx: optax.GradientTransformation (already initialized).

    Returns:
      new_params: updated parameters after one gradient step.
      new_opt_state: updated optimizer state.
      metrics: dict of scalar metrics (loss, acc).
    """
    def loss_fn(params):
        logits = model.apply({"params": params}, x)
        loss, metrics = loss_and_metrics(logits, y)
        return loss, metrics

    # compute gradients (loss is scalar, metrics is auxiliary)
    (loss, metrics), grads = jax.value_and_grad(loss_fn, has_aux=True)(params)

    # optax update: compute parameter updates and new optimizer state
    updates, new_opt_state = tx.update(grads, opt_state, params)
    new_params = optax.apply_updates(params, updates)
    return new_params, new_opt_state, metrics

# jit: last argument should be static because it is an object
train_step = jax.jit(train_step, static_argnames=("tx",))

# %% [markdown]
# # Batch creation:

# %%
# create a batch from the training data
def get_batch(text_int, B, T):
    """Create a random batch of data from text_int.

    Args:
      text_int: 1D array of token ids.
      B: batch size (number of sequences).
      T: sequence length (number of tokens per sequence).

    Returns:
      x: (B, T) int array input tokens.
      y: (B, T) int array target tokens.
    """
    # choose random starting indices for each sequence in the batch
    ix = np.random.randint(0, len(text_int) - T, size=B)
    # inputs are text from i to i+T
    x = np.stack([text_int[i:i+T] for i in ix])
    # targets are text from i+1 to i+T+1
    y = np.stack([text_int[i+1:i+T+1] for i in ix])
    return jnp.array(x, dtype=jnp.int32), jnp.array(y, dtype=jnp.int32)

# %% [markdown]
# # **Experimental Procedure**
# For the *Optimisation* part of the model, we first run individual time-based experiments for each hyperparameter to quickly observe the effect of each hyperparameter in isolation, identify reasonable ranges, and avoid inefficient combinations. In the second stage, we explore selected combinations of hyperparameters, testing a few different configurations to capture their joint effects on model performance.
#
# ### **Hyperparameters Tested:**
# - Learning rate ```lr```
# - Batch size ```B```
# - Sequence length ```T```
#
#
# # **Experiment 1: Learning Rate**
# We run a 10-min trial for each ```lr``` value [1e-3, 1e-4, 1e-5].
#
#
# **Optimiser chosen:** AdamW, plus gradient clipping
# **LR Schedule chosen:** Cosine Decay with Warmup
#
# For this experiment, the default model parameters were used (```d_model = 256```, ```n_layers = 2```).

# %%
# ---- CONFIG ----
learning_rates = [1e-3, 1e-4, 1e-5]
runtime_limit = 600          # seconds (~10min)
full_niter = 100_000         # your true final planned training length
record_interval = 20
B, T = 128, 64
B_test, T_test = 1034, 32

experiment_results = []

# cosine warmup schedule (full schedule)
warmup_steps = int(0.1 * full_niter)
decay_steps  = full_niter - warmup_steps

def make_full_cosine(base_lr):
    def schedule(step):
        s = jnp.minimum(step, 1_000_000)
        warmup_lr = base_lr * (s / warmup_steps)
        cosine_decay = 0.5 * (1 + jnp.cos(jnp.pi * (s - warmup_steps) / decay_steps))
        cosine_lr = base_lr * cosine_decay
        return jnp.where(s < warmup_steps, warmup_lr, cosine_lr)
    return schedule


for lr in learning_rates:
    print(f"=== running lr={lr} ===")

    params_exp = params  # reset model

    schedule_fn = make_full_cosine(lr)
    tx = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=schedule_fn, weight_decay=1e-4)
    )
    opt_state_exp = tx.init(params_exp)

    # histories
    train_loss_history, train_acc_history, train_acc_last_history = [], [], []
    test_loss_history,  test_acc_history,  test_acc_last_history  = [], [], []
    lr_history = []
    time_history, time_test_history = [], []

    time_start = time.time()
    step = 0

    while time.time() - time_start < runtime_limit:

        # train batch
        input, target = get_batch(train_text_int, B, T)
        params_exp, opt_state_exp, metrics = train_step(params_exp, opt_state_exp, input, target, tx)

        # log train
        train_loss_history.append(float(metrics['loss']))
        train_acc_history.append(float(metrics['acc']))
        train_acc_last_history.append(float(metrics['acc_last']))
        time_history.append(time.time() - time_start)

        # numeric LR
        current_lr = float(schedule_fn(step))
        lr_history.append(current_lr)

        # periodic test
        if step % (record_interval * 5) == 0:
            test_input, test_target = get_batch(test_text_int, B_test, T_test)
            test_logits = model.apply({"params": params_exp}, test_input)
            test_loss, test_metrics = loss_and_metrics(test_logits, test_target)

            test_loss_history.append(float(test_loss))
            test_acc_history.append(float(test_metrics['acc']))
            test_acc_last_history.append(float(test_metrics['acc_last']))
            time_test_history.append(time.time() - time_start)

        step += 1

    print(f"done lr={lr} steps={step}")

    experiment_results.append({
        'lr': lr,
        'steps': step,
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'train_acc_last': train_acc_last_history,
        'test_loss': test_loss_history,
        'test_acc': test_acc_history,
        'test_acc_last': test_acc_last_history,
        'lr_history': lr_history,
        'train_time': time_history,
        'test_time': time_test_history
    })
# Out:
# === running lr=0.001 ===
# done lr=0.001 steps=16747
# === running lr=0.0001 ===
# done lr=0.0001 steps=16743
# === running lr=1e-05 ===
# done lr=1e-05 steps=16636

# %%
print("\n=== Experiment Summary (Final Test Performance) ===")
for exp in experiment_results:
    final_test_loss = exp['test_loss'][-1] if exp['test_loss'] else None
    final_test_acc = exp['test_acc'][-1] * 100 if exp['test_acc'] else None
    final_test_acc_last = exp['test_acc_last'][-1] * 100 if exp['test_acc_last'] else None
    print(f"LR={exp['lr']:<8}"
          f"| Test Loss={final_test_loss:.4f} | Test Acc={final_test_acc:.2f}% | Test Acc (Last Char)={final_test_acc_last:.2f}%")
# Out:
# === Experiment Summary (Final Test Performance) ===
# LR=0.001   | Test Loss=1.3538 | Test Acc=57.64% | Test Acc (Last Char)=58.03%
# LR=0.0001  | Test Loss=1.4372 | Test Acc=55.64% | Test Acc (Last Char)=54.45%
# LR=1e-05   | Test Loss=1.8176 | Test Acc=44.66% | Test Acc (Last Char)=45.16%

# %% [markdown]
# Based on the results above, ```lr = 0.001``` has the best test loss (1.35) and test accuracy (57.6%). However, since the training schedule includes a cosine decay with warmup and we only ran the experiments for 10 minutes, the chosen learning rate primarily reflects the early-stage behavior of the model. The apparent superiority of ```lr = 0.001``` may be influenced by the warmup phase and the initial portion of the cosine decay, and longer training could shift the optimal learning rate, as slower or faster decay dynamics may lead to different convergence patterns or generalisation performance.
#
# Also, all variants of Experiment 1 did not consider tuning other parameters (e.g. ```model_d```, ```n_layers```). All parameters were kept constant except ```learning_rate```.

# %%
plt.figure()
for exp in experiment_results:
    lr = exp['lr']
    t  = exp['train_time']
    L  = exp['train_loss']
    plt.plot(t, L, label=f"lr={lr:g}")

plt.xlabel("time (s)")
plt.ylabel("train loss")
plt.title("train loss vs time")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
for exp in experiment_results:
    lr = exp['lr']
    t  = exp['test_time']
    L  = exp['test_loss']
    plt.plot(t, L, label=f"lr={lr:g}")

plt.xlabel("time (s)")
plt.ylabel("test loss")
plt.title("test loss vs time")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
for exp in experiment_results:
    lr = exp['lr']
    t  = exp['train_time']
    lr_hist = exp['lr_history']
    plt.plot(t, lr_hist, label=f"lr={lr:g}")

plt.xlabel("time (s)")
plt.ylabel("learning rate")
plt.title("learning rate vs time")
plt.legend()
plt.grid(True)
plt.show()

# %%
# B = 1
# seed = 42
# rng = jax.random.PRNGKey(seed)
# prompt = "hello my fri"
# # prompt_int = encode(prompt.lower())
# prompt_int = jnp.array([ [char_to_int.get(c, len(char_set)) for c in prompt.lower()[:64]] ], dtype=jnp.int32)

# gen_len = 1000
# out_ids = generation.generate_tokens(model, params, rng, prompt_int, gen_len, block_size=64,
#                           temperature=0.7, sample=True)
# print('generated ids shape:', out_ids.shape)
# print('generated text:')
# generated_text = ''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0]))
# # concatenate with prompt
# print(prompt + generated_text)
# #print(''.join(int_to_char.get(int(x), '?') for x in list(out_ids[0])))

# %% [markdown]
# # **Experiment 2: Batch Size**
# For testing batch size, we will normalise compute (use scaling-law fairness) by keeping ```B * T * Steps``` constant.
#
# We test a few different ```B``` values ```[32, 64, 128, 256]```.
# Based on the results of Experiment 1, we use ```lr = 0.001```. We also changed the model parameters (```d_model = 256 -> 512```, ```n_layers = 2 -> 4```) for this experiment.

# %%
# ---- CONFIG ----
lr = 1e-3
full_niter = 100_000
record_interval = 20

batch_sizes = [32, 64, 128, 256]

B_test, T_test = 1034, 32
T = 64          # fixed sequence length

experiment_results = []

# === BASELINE FOR SCALING LAW ===
B_base = 64
S_base = 8000   # chosen baseline steps
TOTAL_TOKENS = B_base * T * S_base

print("Total compute tokens =", TOTAL_TOKENS)

# cosine warmup schedule (defined over full schedule)
warmup_steps = int(0.1 * full_niter)
decay_steps  = full_niter - warmup_steps

def make_full_cosine(base_lr):
    def schedule(step):
        s = jnp.minimum(step, full_niter)  # allow large virtual steps
        warmup_lr = base_lr * (s / warmup_steps)
        cosine_decay = 0.5 * (1 + jnp.cos(jnp.pi * (s - warmup_steps) / decay_steps))
        cosine_lr = base_lr * cosine_decay
        return jnp.where(s < warmup_steps, warmup_lr, cosine_lr)
    return schedule


# ================= MAIN LOOP (compute-normalized batch sweep) =================
import time

for B in batch_sizes:

    # ---- scaling-law fair steps ----
    steps_for_B = TOTAL_TOKENS // (B * T)

    print(f"\n=== running batch_size={B} | steps={steps_for_B} ===")

    params_exp = params  # reset model

    schedule_fn = make_full_cosine(lr)
    tx = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=schedule_fn, weight_decay=1e-4)
    )
    opt_state_exp = tx.init(params_exp)

    # histories
    train_loss_history, train_acc_history, train_acc_last_history = [], [], []
    test_loss_history,  test_acc_history,  test_acc_last_history  = [], [], []
    lr_history = []
    time_history, time_test_history = [], []

    time_start = time.time()

    for step in range(int(steps_for_B)):

        # train batch
        x, y = get_batch(train_text_int, B, T)
        params_exp, opt_state_exp, metrics = train_step(params_exp, opt_state_exp, x, y, tx)

        # log training
        train_loss_history.append(float(metrics['loss']))
        train_acc_history.append(float(metrics['acc']))
        train_acc_last_history.append(float(metrics['acc_last']))
        time_history.append(time.time() - time_start)

        # LR
        lr_history.append(float(schedule_fn(step)))

        # periodic test
        if step % (record_interval * 5) == 0:
            tx_test, ty_test = get_batch(test_text_int, B_test, T_test)
            logits = model.apply({"params": params_exp}, tx_test)
            test_loss, test_metrics = loss_and_metrics(logits, ty_test)

            test_loss_history.append(float(test_loss))
            test_acc_history.append(float(test_metrics["acc"]))
            test_acc_last_history.append(float(test_metrics["acc_last"]))
            time_test_history.append(time.time() - time_start)

    print(f"done batch_size={B} steps={steps_for_B}")

    experiment_results.append({
        'batch_size': B,
        'steps': int(steps_for_B),
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'train_acc_last': train_acc_last_history,
        'test_loss': test_loss_history,
        'test_acc': test_acc_history,
        'test_acc_last': test_acc_last_history,
        'lr_history': lr_history,
        'train_time': time_history,
        'test_time': time_test_history
    })
# Out:
# Total compute tokens = 32768000
#
# === running batch_size=32 | steps=16000 ===
# done batch_size=32 steps=16000
#
# === running batch_size=64 | steps=8000 ===
# done batch_size=64 steps=8000
#
# === running batch_size=128 | steps=4000 ===
# done batch_size=128 steps=4000
#
# === running batch_size=256 | steps=2000 ===
# done batch_size=256 steps=2000

# %%
print("\n=== Experiment Summary (Final Test Performance) ===")
for exp in experiment_results:
    final_test_loss = exp['test_loss'][-1] if exp['test_loss'] else None
    final_test_acc = exp['test_acc'][-1] * 100 if exp['test_acc'] else None
    final_test_acc_last = exp['test_acc_last'][-1] * 100 if exp['test_acc_last'] else None
    steps = exp['steps']

    print(f"B={exp['batch_size']:<5} "
          f"| steps={steps:<6} "
          f"| Test Loss={final_test_loss:.4f} "
          f"| Test Acc={final_test_acc:.2f}% "
          f"| Test Acc (Last Char)={final_test_acc_last:.2f}%")
# Out:
# === Experiment Summary (Final Test Performance) ===
# B=32    | steps=16000  | Test Loss=1.3585 | Test Acc=57.60% | Test Acc (Last Char)=60.25%
# B=64    | steps=8000   | Test Loss=1.3911 | Test Acc=56.49% | Test Acc (Last Char)=59.96%
# B=128   | steps=4000   | Test Loss=1.4154 | Test Acc=56.00% | Test Acc (Last Char)=58.61%
# B=256   | steps=2000   | Test Loss=1.5251 | Test Acc=53.35% | Test Acc (Last Char)=58.90%

# %%
import matplotlib.pyplot as plt
import numpy as np

# === FIXED PARAMS FOR BATCH-SIZE EXPERIMENT ===
T = 64   # sequence length is fixed for this experiment

# === Compute tokens processed ===
def compute_tokens(exp):
    B = exp['batch_size']
    steps = len(exp['train_loss'])
    tokens = np.arange(steps) * (B * T)
    return tokens

# === Final test accuracy per batch size ===
final_accs = [
    exp['test_acc'][-1] * 100 if exp['test_acc'] else None
    for exp in experiment_results
]
batch_sizes = [exp['batch_size'] for exp in experiment_results]

# === Create 4-in-1 figure ===
plt.figure(figsize=(14, 10))

# -------------------------------------------------
# 1. Train Loss vs Tokens
# -------------------------------------------------
plt.subplot(2, 2, 1)
for exp in experiment_results:
    tokens = compute_tokens(exp)
    plt.plot(tokens, exp['train_loss'], label=f"B={exp['batch_size']}")
plt.xlabel("Tokens Processed (B × T × steps)")
plt.ylabel("Train Loss")
plt.title("Train Loss vs Tokens (Compute-normalized)")
plt.legend()
plt.grid(True)

# -------------------------------------------------
# 2. Test Loss vs Tokens
# -------------------------------------------------
plt.subplot(2, 2, 2)
for exp in experiment_results:
    tokens = compute_tokens(exp)
    test_loss = exp['test_loss']

    # test loss is logged sparsely; rescale tokens
    if len(test_loss) > 1:
        test_tokens = np.linspace(tokens[0], tokens[-1], len(test_loss))
    else:
        test_tokens = tokens[:len(test_loss)]

    plt.plot(test_tokens, test_loss, label=f"B={exp['batch_size']}")
plt.xlabel("Tokens Processed (B × T × steps)")
plt.ylabel("Test Loss")
plt.title("Test Loss vs Tokens (Compute-normalized)")
plt.legend()
plt.grid(True)

# -------------------------------------------------
# 3. Final Test Accuracy vs Batch Size
# -------------------------------------------------
plt.subplot(2, 2, 3)
plt.plot(batch_sizes, final_accs, marker='o')
plt.xlabel("Batch Size")
plt.ylabel("Final Test Accuracy (%)")
plt.title("Final Test Accuracy vs Batch Size")
plt.grid(True)

# -------------------------------------------------
# 4. Train Loss vs Wall-clock Time
# -------------------------------------------------
plt.subplot(2, 2, 4)
for exp in experiment_results:
    plt.plot(exp['train_time'], exp['train_loss'], label=f"B={exp['batch_size']}")
plt.xlabel("Time (s)")
plt.ylabel("Train Loss")
plt.title("Train Loss vs Wall-clock Time (Speed Comparison)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Experiment 3: Sequence Length ```T```**
# For testing batch size, we will normalise compute (use scaling-law fairness) by keeping ```B * T * Steps``` constant.
#
# We test a few different ```T``` values ```[32, 64, 128]``` with ```B = 64```, since ```B = 64``` showed the optimal performance in Experiment 2.
# For all individual experiments, ```B_test, T_test = 1034, 32``` are kept constant for meaningful comparisons.

# %%
# ---- CONFIG ----
lr = 1e-3
full_niter = 100_000
record_interval = 20

# sequence lengths to experiment with
seq_lengths = [32, 64, 128]

# fixed batch size
B = 64   # optimal batch size from previous experiment

# fixed test params
B_test, T_test = 1034, 32

experiment_results = []

# baseline for compute normalization
T_base = 64
S_base = 8000  # baseline steps
TOTAL_TOKENS = B * T_base * S_base
print("Total tokens (compute budget) =", TOTAL_TOKENS)

# cosine warmup schedule (full schedule)
warmup_steps = int(0.1 * full_niter)
decay_steps  = full_niter - warmup_steps

def make_full_cosine(base_lr):
    def schedule(step):
        s = jnp.minimum(step, full_niter)
        warmup_lr = base_lr * (s / warmup_steps)
        cosine_decay = 0.5 * (1 + jnp.cos(jnp.pi * (s - warmup_steps) / decay_steps))
        cosine_lr = base_lr * cosine_decay
        return jnp.where(s < warmup_steps, warmup_lr, cosine_lr)
    return schedule

# ================= MAIN LOOP (compute-normalized sequence length sweep) =================
import time

for T in seq_lengths:
    # scaling-law steps
    steps_for_T = TOTAL_TOKENS // (B * T)
    print(f"\n=== running seq_length={T} | steps={steps_for_T} ===")

    params_exp = params  # reset model

    schedule_fn = make_full_cosine(lr)
    tx = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=schedule_fn, weight_decay=1e-4)
    )
    opt_state_exp = tx.init(params_exp)

    # histories
    train_loss_history, train_acc_history, train_acc_last_history = [], [], []
    test_loss_history,  test_acc_history,  test_acc_last_history  = [], [], []
    lr_history = []
    time_history, time_test_history = [], []

    time_start = time.time()

    for step in range(int(steps_for_T)):

        # train batch
        x, y = get_batch(train_text_int, B, T)
        params_exp, opt_state_exp, metrics = train_step(params_exp, opt_state_exp, x, y, tx)

        # log training
        train_loss_history.append(float(metrics['loss']))
        train_acc_history.append(float(metrics['acc']))
        train_acc_last_history.append(float(metrics['acc_last']))
        time_history.append(time.time() - time_start)

        # LR
        lr_history.append(float(schedule_fn(step)))

        # periodic test
        if step % (record_interval * 5) == 0:
            tx_test, ty_test = get_batch(test_text_int, B_test, T_test)
            logits = model.apply({"params": params_exp}, tx_test)
            test_loss, test_metrics = loss_and_metrics(logits, ty_test)

            test_loss_history.append(float(test_loss))
            test_acc_history.append(float(test_metrics["acc"]))
            test_acc_last_history.append(float(test_metrics["acc_last"]))
            time_test_history.append(time.time() - time_start)

    print(f"done seq_length={T} steps={steps_for_T}")

    experiment_results.append({
        'seq_length': T,
        'steps': int(steps_for_T),
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'train_acc_last': train_acc_last_history,
        'test_loss': test_loss_history,
        'test_acc': test_acc_history,
        'test_acc_last': test_acc_last_history,
        'lr_history': lr_history,
        'train_time': time_history,
        'test_time': time_test_history
    })
# Out:
# Total tokens (compute budget) = 32768000
#
# === running seq_length=32 | steps=16000 ===
# done seq_length=32 steps=16000
#
# === running seq_length=64 | steps=8000 ===
# done seq_length=64 steps=8000
#
# === running seq_length=128 | steps=4000 ===
# done seq_length=128 steps=4000

# %%
print("\n=== Experiment Summary (Final Test Performance) ===")
for exp in experiment_results:
    final_test_loss = exp['test_loss'][-1] if exp['test_loss'] else None
    final_test_acc = exp['test_acc'][-1] * 100 if exp['test_acc'] else None
    final_test_acc_last = exp['test_acc_last'][-1] * 100 if exp['test_acc_last'] else None
    steps = exp['steps']

    print(f"T={exp['seq_length']:<8}"
          f"| Steps={steps:<6}"
          f"| Test Loss={final_test_loss:.4f} "
          f"| Test Acc={final_test_acc:.2f}% "
          f"| Test Acc (Last Char)={final_test_acc_last:.2f}%")
# Out:
# === Experiment Summary (Final Test Performance) ===
# T=32      | Steps=16000 | Test Loss=1.3634 | Test Acc=57.31% | Test Acc (Last Char)=57.54%
# T=64      | Steps=8000  | Test Loss=1.3907 | Test Acc=56.53% | Test Acc (Last Char)=58.22%
# T=128     | Steps=4000  | Test Loss=1.4777 | Test Acc=53.92% | Test Acc (Last Char)=60.15%

# %%
import matplotlib.pyplot as plt
import numpy as np

# ---- FIXED BATCH SIZE ----
B = 64  # optimal batch size from previous experiment

# ---- Compute tokens processed per step ----
def compute_tokens(exp):
    T = exp['seq_length']
    steps = len(exp['train_loss'])
    tokens = np.arange(steps) * (B * T)
    return tokens

# ---- Final test accuracy per sequence length ----
seq_lengths = [exp['seq_length'] for exp in experiment_results]
final_accs = [
    exp['test_acc'][-1] * 100 if exp['test_acc'] else None
    for exp in experiment_results
]

# ---- Create 4-in-1 figure ----
plt.figure(figsize=(14, 10))

# 1️⃣ Train Loss vs Tokens
plt.subplot(2, 2, 1)
for exp in experiment_results:
    tokens = compute_tokens(exp)
    plt.plot(tokens, exp['train_loss'], label=f"T={exp['seq_length']}")
plt.xlabel("Tokens Processed (B × T × steps)")
plt.ylabel("Train Loss")
plt.title("Train Loss vs Tokens (Compute-normalized)")
plt.legend()
plt.grid(True)

# 2️⃣ Test Loss vs Tokens
plt.subplot(2, 2, 2)
for exp in experiment_results:
    tokens = compute_tokens(exp)
    test_loss = exp['test_loss']

    # rescale test tokens if test_loss is logged sparsely
    if len(test_loss) > 1:
        test_tokens = np.linspace(tokens[0], tokens[-1], len(test_loss))
    else:
        test_tokens = tokens[:len(test_loss)]

    plt.plot(test_tokens, test_loss, label=f"T={exp['seq_length']}")
plt.xlabel("Tokens Processed (B × T × steps)")
plt.ylabel("Test Loss")
plt.title("Test Loss vs Tokens (Compute-normalized)")
plt.legend()
plt.grid(True)

# 3️⃣ Final Test Accuracy vs Sequence Length
plt.subplot(2, 2, 3)
plt.plot(seq_lengths, final_accs, marker='o')
plt.xlabel("Sequence Length")
plt.ylabel("Final Test Accuracy (%)")
plt.title("Final Test Accuracy vs Sequence Length")
plt.grid(True)

# 4️⃣ Train Loss vs Wall-clock Time
plt.subplot(2, 2, 4)
for exp in experiment_results:
    plt.plot(exp['train_time'], exp['train_loss'], label=f"T={exp['seq_length']}")
plt.xlabel("Time (s)")
plt.ylabel("Train Loss")
plt.title("Train Loss vs Wall-clock Time (Speed Comparison)")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Experiment 4: Combination of Hyperparameters**
# We do a grid search of the best configurations of parameters with the following hyperparameter values:
# ```
# T = [32, 64]
# B = [64, 128]
# LR = [1e-3, 1e-4]
# ```
#
# To fairly compare configurations, we equalise total compute by fixing the no. of token-updates (```B * T * Steps```). Each configuration is run until the total tokens processed matches a constant budget.

# %%
# ==== CONFIG ====
T_values  = [32, 64]
B_values  = [64, 128]
LR_values = [1e-3, 1e-4]

max_steps = 10_000
full_niter = max_steps        # LR schedule always defined over 10k virtual steps
record_interval = 20
B_test, T_test = 1034, 32

# ---- define constant compute budget (tokens processed) ----
BASE_T = 32
BASE_B = 64
BASE_STEPS = max_steps

TOTAL_TOKENS = BASE_T * BASE_B * BASE_STEPS
print("Total compute budget (tokens):", TOTAL_TOKENS)

experiment_results = []

# ---- cosine schedule ----
warmup_steps = int(0.1 * full_niter)
decay_steps  = full_niter - warmup_steps

def make_full_cosine(base_lr):
    def schedule(step):
        s = jnp.minimum(step, full_niter)  # schedule defined over full range
        warmup_lr = base_lr * (s / warmup_steps)
        cosine_decay = 0.5 * (1 + jnp.cos(jnp.pi * (s - warmup_steps) / decay_steps))
        cosine_lr = base_lr * cosine_decay
        return jnp.where(s < warmup_steps, warmup_lr, cosine_lr)
    return schedule


# ==== GRID SEARCH LOOP ====
import itertools
import time

for (T, B, lr) in itertools.product(T_values, B_values, LR_values):

    # ---- compute fair number of steps for this config ----
    steps_for_config = TOTAL_TOKENS // (B * T)
    print(f"\n=== Running T={T}, B={B}, LR={lr} | Steps={steps_for_config} ===")

    # reset model parameters
    params_exp = params

    # learning-rate schedule
    schedule_fn = make_full_cosine(lr)
    tx = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=schedule_fn, weight_decay=1e-4)
    )
    opt_state_exp = tx.init(params_exp)

    # logs
    train_loss_history, train_acc_history, train_acc_last_history = [], [], []
    test_loss_history,  test_acc_history,  test_acc_last_history  = [], [], []
    lr_history = []
    time_history, time_test_history = [], []

    time_start = time.time()

    # ---- TRAINING LOOP (variable steps, fixed compute budget) ----
    for step in range(int(steps_for_config)):

        x, y = get_batch(train_text_int, B, T)
        params_exp, opt_state_exp, metrics = train_step(params_exp, opt_state_exp, x, y, tx)

        # record training
        train_loss_history.append(float(metrics["loss"]))
        train_acc_history.append(float(metrics["acc"]))
        train_acc_last_history.append(float(metrics["acc_last"]))
        time_history.append(time.time() - time_start)

        # record LR
        # NOTE: schedule is still based on "virtual" 0..10k steps
        lr_history.append(float(schedule_fn(step)))

        # periodic test
        if step % (record_interval * 5) == 0:
            tx_test, ty_test = get_batch(test_text_int, B_test, T_test)
            logits = model.apply({"params": params_exp}, tx_test)
            test_loss, test_metrics = loss_and_metrics(logits, ty_test)

            test_loss_history.append(float(test_loss))
            test_acc_history.append(float(test_metrics["acc"]))
            test_acc_last_history.append(float(test_metrics["acc_last"]))
            time_test_history.append(time.time() - time_start)

    print(f"Finished T={T}, B={B}, LR={lr} | Steps={steps_for_config}")

    # save results
    experiment_results.append({
        "T": T,
        "B": B,
        "lr": lr,
        "steps": int(steps_for_config),
        "train_loss": train_loss_history,
        "train_acc": train_acc_history,
        "train_acc_last": train_acc_last_history,
        "test_loss": test_loss_history,
        "test_acc": test_acc_history,
        "test_acc_last": test_acc_last_history,
        "lr_history": lr_history,
        "train_time": time_history,
        "test_time": time_test_history,
    })
# Out:
# Total compute budget (tokens): 20480000
#
# === Running T=32, B=64, LR=0.001 | Steps=10000 ===
# Finished T=32, B=64, LR=0.001 | Steps=10000
#
# === Running T=32, B=64, LR=0.0001 | Steps=10000 ===
# Finished T=32, B=64, LR=0.0001 | Steps=10000
#
# === Running T=32, B=128, LR=0.001 | Steps=5000 ===
# Finished T=32, B=128, LR=0.001 | Steps=5000
#
# === Running T=32, B=128, LR=0.0001 | Steps=5000 ===
# Finished T=32, B=128, LR=0.0001 | Steps=5000
#
# === Running T=64, B=64, LR=0.001 | Steps=5000 ===
# Finished T=64, B=64, LR=0.001 | Steps=5000
#
# === Running T=64, B=64, LR=0.0001 | Steps=5000 ===
# Finished T=64, B=64, LR=0.0001 | Steps=5000
#
# === Running T=64, B=128, LR=0.001 | Steps=2500 ===
# Finished T=64, B=128, LR=0.001 | Steps=2500
#
# === Running T=64, B=128, LR=0.0001 | Steps=2500 ===
# Finished T=64, B=128, LR=0.0001 | Steps=2500

# %%
print("\n=== Experiment Summary (Final Test Performance) ===")
for exp in experiment_results:
    final_test_loss = exp['test_loss'][-1] if exp['test_loss'] else None
    final_test_acc  = exp['test_acc'][-1] * 100 if exp['test_acc'] else None
    final_test_last = exp['test_acc_last'][-1] * 100 if exp['test_acc_last'] else None
    steps = exp['steps']

    print(
        f"T={exp['T']:<3} | B={exp['B']:<4} | LR={exp['lr']:<8} | Steps={steps:<5} "
        f"| TestLoss={final_test_loss:.4f} | TestAcc={final_test_acc:.2f}% "
        f"| LastChar={final_test_last:.2f}%"
    )
# Out:
# === Experiment Summary (Final Test Performance) ===
# T=32  | B=64   | LR=0.001    | Steps=10000 | TestLoss=1.3389 | TestAcc=57.96% | LastChar=61.90%
# T=32  | B=64   | LR=0.0001   | Steps=10000 | TestLoss=1.3941 | TestAcc=56.48% | LastChar=62.96%
# T=32  | B=128  | LR=0.001    | Steps=5000  | TestLoss=1.3453 | TestAcc=57.69% | LastChar=62.19%
# T=32  | B=128  | LR=0.0001   | Steps=5000  | TestLoss=1.4093 | TestAcc=56.22% | LastChar=58.51%
# T=64  | B=64   | LR=0.001    | Steps=5000  | TestLoss=1.3679 | TestAcc=57.18% | LastChar=59.57%
# T=64  | B=64   | LR=0.0001   | Steps=5000  | TestLoss=1.4594 | TestAcc=54.41% | LastChar=59.19%
# T=64  | B=128  | LR=0.001    | Steps=2500  | TestLoss=1.4151 | TestAcc=55.41% | LastChar=59.48%
# T=64  | B=128  | LR=0.0001   | Steps=2500  | TestLoss=1.5115 | TestAcc=53.61% | LastChar=54.35%

# %%
import matplotlib.pyplot as plt
import numpy as np

# ---- function to compute tokens processed ----
def compute_tokens(exp):
    B = exp['B']
    T = exp['T']
    steps = len(exp['train_loss'])
    return np.arange(steps) * (B * T)

# ---- Prepare colors/markers for visualization ----
import itertools
colors = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6']
markers = ['o', 's', '^', 'D', 'v', '*']

# ---- Create figure ----
plt.figure(figsize=(16, 12))

# 1️⃣ Train Loss vs Tokens
plt.subplot(2, 2, 1)
for i, exp in enumerate(experiment_results):
    tokens = compute_tokens(exp)
    plt.plot(tokens, exp['train_loss'],
             label=f"T={exp['T']} B={exp['B']} LR={exp['lr']}",
             color=colors[i % len(colors)], marker=markers[i % len(markers)], markevery=200)
plt.xlabel("Tokens Processed (B × T × steps)")
plt.ylabel("Train Loss")
plt.title("Train Loss vs Tokens")
plt.legend(fontsize=8)
plt.grid(True)

# 2️⃣ Test Loss vs Tokens
plt.subplot(2, 2, 2)
for i, exp in enumerate(experiment_results):
    tokens = compute_tokens(exp)
    test_loss = exp['test_loss']
    if len(test_loss) > 1:
        test_tokens = np.linspace(tokens[0], tokens[-1], len(test_loss))
    else:
        test_tokens = tokens[:len(test_loss)]
    plt.plot(test_tokens, test_loss,
             label=f"T={exp['T']} B={exp['B']} LR={exp['lr']}",
             color=colors[i % len(colors)], marker=markers[i % len(markers)], markevery=5)
plt.xlabel("Tokens Processed (B × T × steps)")
plt.ylabel("Test Loss")
plt.title("Test Loss vs Tokens")
plt.legend(fontsize=8)
plt.grid(True)

# 3️⃣ Final Test Accuracy vs Config Index
plt.subplot(2, 2, 3)
final_accs = [exp['test_acc'][-1]*100 for exp in experiment_results]
config_labels = [f"T{exp['T']}_B{exp['B']}_LR{exp['lr']}" for exp in experiment_results]
plt.bar(range(len(experiment_results)), final_accs, color='C0')
plt.xticks(range(len(experiment_results)), config_labels, rotation=45, ha='right', fontsize=8)
plt.ylabel("Final Test Accuracy (%)")
plt.title("Final Test Accuracy per Configuration")
plt.tight_layout()

# 4️⃣ Train Loss vs Wall-clock Time
plt.subplot(2, 2, 4)
for i, exp in enumerate(experiment_results):
    plt.plot(exp['train_time'], exp['train_loss'],
             label=f"T={exp['T']} B={exp['B']} LR={exp['lr']}",
             color=colors[i % len(colors)])
plt.xlabel("Time (s)")
plt.ylabel("Train Loss")
plt.title("Train Loss vs Wall-clock Time")
plt.legend(fontsize=8)
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_48/102576529.py:72: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %% [markdown]
# ## **Experiment X: LR + Model Dimensions + N Layers**
# Ran out of compute

# %%
import itertools

# ---- CONFIG ----
learning_rates = [1e-3, 1e-4, 1e-5]
model_dims = [256, 512, 768]
num_layers_list = [4, 6, 8]

runtime_limit = 300        # seconds (~ 5 min)
full_niter = 100_000       # total planned iterations for schedule
record_interval = 20

B, T = 256, 64
B_test, T_test = 1034, 32

experiment_results = []

# cosine warmup schedule (full schedule)
warmup_steps = int(0.1 * full_niter)
decay_steps  = full_niter - warmup_steps

def make_full_cosine(base_lr):
    def schedule(step):
        s = jnp.minimum(step, 1_000_000)
        warmup_lr = base_lr * (s / warmup_steps)
        cosine_decay = 0.5 * (1 + jnp.cos(jnp.pi * (s - warmup_steps) / decay_steps))
        cosine_lr = base_lr * cosine_decay
        return jnp.where(s < warmup_steps, warmup_lr, cosine_lr)
    return schedule


# ---- GRID SEARCH ----
for lr, dim, n_layers in itertools.product(learning_rates, model_dims, num_layers_list):
    print(f"=== Running lr={lr}, dim={dim}, n_layers={n_layers} ===")

    # Initialize model with the given parameters
    model, params_exp = create_train_state(key, vocab_size, dim, n_layers, n_heads, max_len) # dim, n_layers are newly defined

    schedule_fn = make_full_cosine(lr)
    tx = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=schedule_fn, weight_decay=1e-4)
    )
    opt_state_exp = tx.init(params_exp)

    # histories
    train_loss_history, train_acc_history, train_acc_last_history = [], [], []
    test_loss_history,  test_acc_history,  test_acc_last_history  = [], [], []
    lr_history = []
    time_history, time_test_history = [], []

    time_start = time.time()
    step = 0

    while time.time() - time_start < runtime_limit:

        # train batch
        input, target = get_batch(train_text_int, B, T)
        params_exp, opt_state_exp, metrics = train_step(params_exp, opt_state_exp, input, target, tx)

        # log train
        train_loss_history.append(float(metrics['loss']))
        train_acc_history.append(float(metrics['acc']))
        train_acc_last_history.append(float(metrics['acc_last']))
        time_history.append(time.time() - time_start)

        # numeric LR
        current_lr = float(schedule_fn(step))
        lr_history.append(current_lr)

        # periodic test
        if step % (record_interval * 5) == 0:
            test_input, test_target = get_batch(test_text_int, B_test, T_test)
            test_logits = model.apply({"params": params_exp}, test_input)
            test_loss, test_metrics = loss_and_metrics(test_logits, test_target)

            test_loss_history.append(float(test_loss))
            test_acc_history.append(float(test_metrics['acc']))
            test_acc_last_history.append(float(test_metrics['acc_last']))
            time_test_history.append(time.time() - time_start)

        step += 1

    print(f"done: lr={lr}, dim={dim}, n_layers={n_layers}, steps={step}")

    experiment_results.append({
        'lr': lr,
        'dim': dim,
        'n_layers': n_layers,
        'steps': step,
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'train_acc_last': train_acc_last_history,
        'test_loss': test_loss_history,
        'test_acc': test_acc_history,
        'test_acc_last': test_acc_last_history,
        'lr_history': lr_history,
        'train_time': time_history,
        'test_time': time_test_history
    })

print("Grid search finished!")
# Out:
# === Running lr=0.001, dim=256, n_layers=4 ===
# done: lr=0.001, dim=256, n_layers=4, steps=821
# === Running lr=0.001, dim=256, n_layers=6 ===

# %% [markdown]
# ## **Experiment X: Learning Rate (runtime = 10 min)**
# ```lr = [1e-3, 2e-3, 3e-3]```

# %%
# ---- CONFIG ----
learning_rates = [1e-3, 2e-3, 3e-3]
runtime_limit = 600          # seconds (~2min)
full_niter = 100_000         # your true final planned training length
record_interval = 20
B, T = 128, 64
B_test, T_test = 1034, 32

experiment_results = []

# cosine warmup schedule (full schedule)
warmup_steps = int(0.1 * full_niter)
decay_steps  = full_niter - warmup_steps

def make_full_cosine(base_lr):
    def schedule(step):
        s = jnp.minimum(step, 1_000_000)
        warmup_lr = base_lr * (s / warmup_steps)
        cosine_decay = 0.5 * (1 + jnp.cos(jnp.pi * (s - warmup_steps) / decay_steps))
        cosine_lr = base_lr * cosine_decay
        return jnp.where(s < warmup_steps, warmup_lr, cosine_lr)
    return schedule


for lr in learning_rates:
    print(f"=== running lr={lr} ===")

    params_exp = params  # reset model

    schedule_fn = make_full_cosine(lr)
    tx = optax.chain(
        optax.clip_by_global_norm(1.0),
        optax.adamw(learning_rate=schedule_fn, weight_decay=1e-4)
    )
    opt_state_exp = tx.init(params_exp)

    # histories
    train_loss_history, train_acc_history, train_acc_last_history = [], [], []
    test_loss_history,  test_acc_history,  test_acc_last_history  = [], [], []
    lr_history = []
    time_history, time_test_history = [], []

    time_start = time.time()
    step = 0

    while time.time() - time_start < runtime_limit:

        # train batch
        input, target = get_batch(train_text_int, B, T)
        params_exp, opt_state_exp, metrics = train_step(params_exp, opt_state_exp, input, target, tx)

        # log train
        train_loss_history.append(float(metrics['loss']))
        train_acc_history.append(float(metrics['acc']))
        train_acc_last_history.append(float(metrics['acc_last']))
        time_history.append(time.time() - time_start)

        # numeric LR
        current_lr = float(schedule_fn(step))
        lr_history.append(current_lr)

        # periodic test
        if step % (record_interval * 5) == 0:
            test_input, test_target = get_batch(test_text_int, B_test, T_test)
            test_logits = model.apply({"params": params_exp}, test_input)
            test_loss, test_metrics = loss_and_metrics(test_logits, test_target)

            test_loss_history.append(float(test_loss))
            test_acc_history.append(float(test_metrics['acc']))
            test_acc_last_history.append(float(test_metrics['acc_last']))
            time_test_history.append(time.time() - time_start)

        step += 1

    print(f"done lr={lr} steps={step}")

    experiment_results.append({
        'lr': lr,
        'steps': step,
        'train_loss': train_loss_history,
        'train_acc': train_acc_history,
        'train_acc_last': train_acc_last_history,
        'test_loss': test_loss_history,
        'test_acc': test_acc_history,
        'test_acc_last': test_acc_last_history,
        'lr_history': lr_history,
        'train_time': time_history,
        'test_time': time_test_history
    })
# Out:
# === running lr=0.001 ===
# done lr=0.001 steps=16602
# === running lr=0.002 ===
# done lr=0.002 steps=16765
# === running lr=0.003 ===
# done lr=0.003 steps=16712

# %%
plt.figure()
for exp in experiment_results:
    lr = exp['lr']
    t  = exp['train_time']
    L  = exp['train_loss']
    plt.plot(t, L, label=f"lr={lr:g}")

plt.xlabel("time (s)")
plt.ylabel("train loss")
plt.title("train loss vs time")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
for exp in experiment_results:
    lr = exp['lr']
    t  = exp['test_time']
    L  = exp['test_loss']
    plt.plot(t, L, label=f"lr={lr:g}")

plt.xlabel("time (s)")
plt.ylabel("test loss")
plt.title("test loss vs time")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure()
for exp in experiment_results:
    lr = exp['lr']
    t  = exp['train_time']
    lr_hist = exp['lr_history']
    plt.plot(t, lr_hist, label=f"lr={lr:g}")

plt.xlabel("time (s)")
plt.ylabel("learning rate")
plt.title("learning rate vs time")
plt.legend()
plt.grid(True)
plt.show()
